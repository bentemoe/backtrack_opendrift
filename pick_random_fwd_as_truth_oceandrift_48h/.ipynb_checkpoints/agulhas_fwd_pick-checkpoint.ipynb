# %%
import os
os.path

from datetime import datetime, timedelta
import cmocean

import pyproj
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import trajan as ta
import pandas as pd

import opendrift
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.physics_methods import wind_drift_factor_from_trajectory, distance_between_trajectories, skillscore_liu_weissberg

import cartopy.crs as ccrs
from matplotlib.lines import Line2D

from scipy.spatial import ConvexHull, convex_hull_plot_2d

# %% [markdown]
# ## Functions

# %%
def reproject(latitude, longitude):
    """Returns the x & y coordinates in meters using a sinusoidal projection"""
    from math import pi, cos, radians
    earth_radius = 6371009 # in meters
    lat_dist = pi * earth_radius / 180.0

    y = [lat * lat_dist for lat in latitude]
    x = [long * lat_dist * cos(radians(lat)) 
                for lat, long in zip(latitude, longitude)]
    return x, y

def area_of_polygon(x, y):
    """Calculates the area of an arbitrary polygon given its verticies"""
    area = 0.0
    for i in range(-1, len(x)-1):
        area += x[i] * (y[i+1] - y[i-1])
    return abs(area) / 2.0

def mean_point(x, y):
    centroid = (sum(x) / len(x), sum(y) / len(y))
    return centroid

# %% [markdown]
# ## FORWARD

# %%
reader_globcur = reader_netCDF_CF_generic.Reader("C:/Users/bente/Documents/THESIS/Globcurrent/*.nc")

# %%
duration = timedelta(hours=48)                # 2 days
start_time = datetime(2023,1,23,3,12,8)
end_time = start_time + duration

# %%
outfile = "D:/backtrack/oceandrift_48h/test_fwd_randompick.nc"

# %% [markdown]
# ### Agulhas Current range

# %%
lons = np.arange(22, 32, .1/2) 
lats = np.arange(-36, -30, .05/2)
corners = [lons[0], lons[-1], lats[0], lats[-1]]
lons, lats = np.meshgrid(lons, lats)

# %%
ofwd = OceanDrift(loglevel=50)
ofwd.add_reader([reader_globcur])
ofwd.seed_elements(lon=lons, lat=lats, radius=0, time=start_time)
ofwd.run(duration=duration, time_step=900, time_step_output=3600, outfile=outfile)

# %%
fwd = xr.open_dataset(outfile)

# %%
traj = np.arange(0,48000,1)

# %%
len(fwd.trajectory)
# Out:
# 48000

# %%
### Calculating lons and lats for the end of the trajectories ### 
lon = []
lat = []
lonend = []
latend = []
for j in range(len(fwd.trajectory)):
    lon.append(fwd.isel(trajectory=j).lon.values)
    lat.append(fwd.isel(trajectory=j).lat.values)
    lonend.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
    latend.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory

geod = pyproj.Geod(ellps='WGS84')
on = np.ones(len(lonend))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       6 for j in range(len(fwd.trajectory)):
#       7     lon.append(fwd.isel(trajectory=j).lon.values)
# ----> 8     lat.append(fwd.isel(trajectory=j).lat.values)
#       9     lonend.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
#      10     latend.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\dataset.py:2920, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2918 var_indexers = {k: v for k, v in indexers.items() if k in var.dims}
#    2919 if var_indexers:
# -> 2920     var = var.isel(var_indexers)
#    2921     if drop and var.ndim == 0 and name in coord_names:
#    2922         coord_names.remove(name)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\variable.py:1135, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1132 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1134 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1135 return self[key]
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\variable.py:811, in Variable.__getitem__(self, key)
#     798 """Return a new Variable object whose contents are consistent with
#     799 getting the provided key from the underlying data.
#     800
#    (...)
#     808 array `x.values` directly.
#     809 """
#     810 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 811 data = as_indexable(self._data)[indexer]
#     812 if new_order:
#     813     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:703, in MemoryCachedArray.__getitem__(self, key)
#     702 def __getitem__(self, key):
# --> 703     return type(self)(_wrap_numpy_scalars(self.array[key]))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:670, in CopyOnWriteArray.__getitem__(self, key)
#     669 def __getitem__(self, key):
# --> 670     return type(self)(_wrap_numpy_scalars(self.array[key]))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:570, in LazilyIndexedArray.__getitem__(self, indexer)
#     568     array = LazilyVectorizedIndexedArray(self.array, self.key)
#     569     return array[indexer]
# --> 570 return type(self)(self.array, self._updated_key(indexer))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:536, in LazilyIndexedArray._updated_key(self, new_key)
#     534         full_key.append(k)
#     535     else:
# --> 536         full_key.append(_index_indexer_1d(k, next(iter_new_key), size))
#     537 full_key = tuple(full_key)
#     539 if all(isinstance(k, integer_types + (slice,)) for k in full_key):
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:288, in _index_indexer_1d(old_indexer, applied_indexer, size)
#     286         indexer = slice_slice(old_indexer, applied_indexer, size)
#     287     else:
# --> 288         indexer = _expand_slice(old_indexer, size)[applied_indexer]
#     289 else:
#     290     indexer = old_indexer[applied_indexer]
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:241, in _expand_slice(slice_, size)
#     240 def _expand_slice(slice_, size):
# --> 241     return np.arange(*slice_.indices(size))
#
# KeyboardInterrupt:

# %%
lon = pd.DataFrame(lon)
lat = pd.DataFrame(lat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 lon = pd.DataFrame(lon)
#       2 lat = pd.DataFrame(lat)
#
# NameError: name 'lon' is not defined

# %%
lon.to_pickle('lon_agulhas_fwd.pkl')
lat.to_pickle('lat_agulhas_fwd.pkl')
np.savetxt('lonend_agulhas_fwd.out', lonend, delimiter=',')
np.savetxt('latend_agulhas_fwd.out', latend, delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 lon.to_pickle('lon_agulhas_fwd.pkl')
#       2 lat.to_pickle('lat_agulhas_fwd.pkl')
#       3 np.savetxt('lonend_agulhas_fwd.out', lonend, delimiter=',')
#
# NameError: name 'lon' is not defined

# %%
lon = pd.read_pickle('C:/Users/bente/Documents/BACKTRACK/pick_random_fwd_as_truth_oceandrift_48h/lon_agulhas_fwd.pkl')
lat = pd.read_pickle('C:/Users/bente/Documents/BACKTRACK/pick_random_fwd_as_truth_oceandrift_48h/lat_agulhas_fwd.pkl')
lonend = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/pick_random_fwd_as_truth_oceandrift_48h/lonend_agulhas_fwd.out')
latend = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/pick_random_fwd_as_truth_oceandrift_48h/latend_agulhas_fwd.out')

# %%
n = []
sepdis_fwd = []
area_fwd = []
ilon = []
ilat = []
startlon = []
startlat = []
a_traj = []
msd_hits = []
for i in range(1000):
    a = np.random.choice(traj)
    a_traj.append(a)
    iloni = fwd.isel(trajectory=a).lon.values[-1]
    ilon.append(iloni)
    ilati = fwd.isel(trajectory=a).lat.values[-1]
    ilat.append(ilati)
    startloni = fwd.isel(trajectory=a).lon.values[0]
    startlon.append(startloni)
    startlati = fwd.isel(trajectory=a).lat.values[0]
    startlat.append(startlati)
    if iloni<1e10 and ilati<1e10:
        geod = pyproj.Geod(ellps='WGS84')
        on = np.ones(len(lonend))
        dummy1, dummy2, dist2incident = geod.inv(lonend, latend, iloni*on, ilati*on)
        hits = pd.DataFrame(np.where(dist2incident<5000))
        lenhits = hits.shape[1]
        n.append(lenhits) 
        
        hit_start_lons = []
        hit_start_lats = []
        for m in range(lenhits):
            hit_start_lons.append(np.array(lon.loc[hits[m]][0]))
            hit_start_lats.append(np.array(lat.loc[hits[m]][0]))
            
        ### calculating sep. dist. point of gravity of hits to drifter obs. location ###
        if len(hit_start_lons)>1: 
            centroid_fwd = mean_point(hit_start_lons, hit_start_lats)
            sepdis_fwd.append(ta.skill.distance_between_trajectories(np.array([startloni]), np.array([startlati]), np.array([centroid_fwd[0]]), np.array([centroid_fwd[1]])))
            sd_hits = []
            for l in range(len(hits)):    
                sd_hits.append(ta.skill.distance_between_trajectories(np.array([hit_start_lons[l]]), np.array([hit_start_lats[l]]), np.array([centroid_fwd[0]]), np.array([centroid_fwd[1]])))
            msd_hits.append(np.mean(sd_hits))
        else:
            sepdis_fwd.append(np.nan)
            msd_hits.append(np.nan)
            
        ### calculating area of convex hull ###
        if lenhits>2 and hit_start_lons.count(hit_start_lons[0]) is not len(hit_start_lons) and hit_start_lats.count(hit_start_lats[0]) is not len(hit_start_lats):
            points = []
            for k in range(lenhits):
                points.append([hit_start_lons[k], hit_start_lats[k]])
            points = np.array(points)
            reshaped_points = points.reshape(-1, 2)
            hull_fwd = ConvexHull(reshaped_points)
            hull_fwd_points = points[hull_fwd.vertices]

            hull_fwd_lon = []
            hull_fwd_lat = []
            for l in range(len(hull_fwd_points)):
                hull_fwd_lon.append(hull_fwd_points[l,0])
                hull_fwd_lat.append(hull_fwd_points[l,1])
            repro_fwd = reproject(hull_fwd_lon, hull_fwd_lat)
            area_fwd.append(area_of_polygon(repro_fwd[0],repro_fwd[1]))
        else: 
            area_fwd.append(np.nan)
    
    else: 
        n.append(np.nan)
        sepdis_fwd.append(np.nan)
        msd_hits.append(np.nan)
        area_fwd.append(np.nan)

# %%
lon
# Out:
#           0          1          2          3          4          5   \
# 0  31.585455  31.587570  31.588192  31.588202  31.587601  31.585592
# 1  31.596735  31.597668  31.597589  31.596453  31.595158  31.591959
# 2  31.560530  31.562895  31.563652  31.563864  31.563368  31.561508
# 3  31.627834  31.629343  31.629633  31.629128  31.628233  31.625748
# 4  31.583393  31.584743  31.584908  31.584158  31.583090  31.580267
# 5  31.608997  31.611616  31.612553  31.613100  31.612848  31.611481
# 6  31.538607  31.541973  31.543316  31.544483  31.544559  31.543663
#
#           6          7          8          9   ...         39         40  \
# 0  31.583786  31.579781  31.576775  31.570766  ...  31.421547  31.419300
# 1  31.589422  31.584166  31.580393  31.573080  ...  31.420702  31.420450
# 2  31.559774  31.555859  31.552893  31.546926  ...  31.406353  31.405678
# 3  31.623659  31.619207  31.615955  31.609566  ...  31.456545  31.453102
# 4  31.577951  31.573059  31.569504  31.562548  ...  31.415625  31.415520
# 5  31.610094  31.606840  31.604317  31.599163  ...  31.469315  31.466377
# 6  31.542517  31.539593  31.537230  31.532278  ...  31.400333  31.398817
#
#           41         42         43         44         45         46  \
# 0  31.415756  31.413733  31.410505  31.408640  31.405619  31.403940
# 1  31.420238  31.420218  31.420321  31.420446  31.420729  31.421019
# 2  31.404778  31.404354  31.403807  31.403555  31.403227  31.403168
# 3  31.447107  31.443367  31.436922  31.432989  31.426493  31.422710
# 4  31.415562  31.415695  31.416063  31.416351  31.416904  31.417362
# 5  31.461224  31.457985  31.452374  31.448885  31.442900  31.439297
# 6  31.396521  31.395262  31.393333  31.392260  31.390574  31.389711
#
#           47         48
# 0  31.401497  31.400640
# 1  31.421827  31.422260
# 2  31.403421  31.403645
# 3  31.416727  31.414444
# 4  31.418455  31.419004
# 5  31.433411  31.431099
# 6  31.388645  31.388348
#
# [7 rows x 49 columns]

# %% [markdown]
# ### BACKWARD

# %%
outfile_back = []
for i in range(1000):
    outfile_back.append("D:/backtrack/oceandrift_48h/random_pick/back_test1002_"+str(i)+".nc")

# %%
for i in range(1000):
    orev = OceanDrift(loglevel=50)
    orev.add_reader([reader_globcur])
    if n[i]>0 and ilon[i]<1e10 and ilat[i]<1e10:
        orev.seed_elements(lon=ilon[i], lat=ilat[i], radius=5000, radius_type='uniform', number=n[i],
                         time=end_time)
        orev.run(duration=duration, time_step=-900, time_step_output=3600, outfile=outfile_back[i])

# %%
sims_back = []
for i in range(1000):
    if n[i]>0 and ilon[i]<1e10 and ilat[i]<1e10:
        sims_back.append(xr.open_dataset(outfile_back[i]))     # For the forward runs with hits
    else: 
        sims_back.append(np.nan)                               # For the forward runs without hits

# %%
sims_back[0]>0
# Out:
# False

# %%
area_back = []
sepdis_back = []
msd_hits_back = []

for i in range(len(sims_back)): 
    if sims_back[i]>0:
        lon = []
        lat = []
        lonend = []
        latend = []
        for j in range(len(sims_back[i].trajectory)):
            lon.append(sims_back[i].isel(trajectory=j).lon.values)
            lat.append(sims_back[i].isel(trajectory=j).lat.values)
            lonend.append(sims_back[i].isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
            latend.append(sims_back[i].isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
       
        ### calculating sep. dist. point of gravity of hits to drifter obs. location ###
        if len(lonend)>1 and len(lonend)<400: 
            centroid_back = mean_point(lonend, latend)
            sepdis_back.append(ta.skill.distance_between_trajectories(np.array([startlon[i]]), np.array([startlat[i]]), np.array([centroid_back[0]]), np.array([centroid_back[1]])))
            sd_hits = []
            for j in range(len(lonend)):
                sd_hits.append(ta.skill.distance_between_trajectories(np.array([lonend[j]]), np.array([latend[j]]), np.array([centroid_back[0]]), np.array([centroid_back[1]])))
            msd_hits_back.append(np.mean(sd_hits))
            
            ### calculating area of convex hull ###
            points_back = []
            for j in range(len(lonend)):
                if lonend[j]<1e10 and latend[j]<1e10:
                    points_back.append([lonend[j], latend[j]])
            points_back = np.array(points_back)

            if len(points_back)>2: 
                hull_back = ConvexHull(points_back)
                hull_back_points = points_back[hull_back.vertices]
                hull_back_lon = []
                hull_back_lat = []
                for l in range(len(hull_back_points)):
                    hull_back_lon.append(hull_back_points[l,0])
                    hull_back_lat.append(hull_back_points[l,1])

                repro_back = reproject(hull_back_lon, hull_back_lat)
                area_back.append(area_of_polygon(repro_back[0],repro_back[1]))

        else:
            area_back.append(np.nan)
            sepdis_back.append(np.nan)
            msd_hits_back.append(np.nan)
    
    else:
        area_back.append(np.nan)
        sepdis_back.append(np.nan)

# %%
points_back
# Out:
# array([[ 31.40064 , -31.297398],
#        [ 31.42226 , -31.216778],
#        [ 31.403645, -31.240248],
#        [ 31.414444, -31.361967],
#        [ 31.419004, -31.213068],
#        [ 31.431099, -31.41456 ],
#        [ 31.388348, -31.27678 ]], dtype=float32)

# %%
area_fwd_new = []
for i in range(len(area_fwd)):
    if area_fwd[i] is not np.nan: 
        area_fwd_new.append(area_fwd[i][0])
    else: 
        area_fwd_new.append(np.nan)

# %%
sepdis_fwd_new = []
sepdis_back_new = []
for i in range(len(sepdis_fwd)):
    if sepdis_fwd[i] is not np.nan: 
        sepdis_fwd_new.append(sepdis_fwd[i][0][0])
    else: 
        sepdis_fwd_new.append(np.nan)
    if sepdis_back[i] is not np.nan: 
        sepdis_back_new.append(sepdis_back[i][0])
    else: 
        sepdis_back_new.append(np.nan)

# %%
np.savetxt('agul1000_area_forward.out', area_fwd_new, delimiter=',')
np.savetxt('agul1000_sepdis_fwd.out', sepdis_fwd_new, delimiter=',')
np.savetxt('agul1000_area_back.out', area_back, delimiter=',')
np.savetxt('agul1000_sepdis_back.out', sepdis_back_new, delimiter=',')
np.savetxt('agul1000_n.out', n, delimiter=',')

# %%
plt.figure(figsize=(16,4))
plt.scatter(range(len(area_back)), area_back, color='red', linestyle='-', label='backward')
plt.scatter(range(len(area_fwd_new)), area_fwd_new, color='blue', linestyle='-', label='forward')

plt.ylim([-10000000,2e8])
plt.legend()
plt.grid()
plt.title('Area convex hull', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Area convex hull')

# %%
area_back_nan = np.array(area_back)[~np.isnan(np.array(area_back))]
area_forward_nan = np.array(area_fwd_new)[~np.isnan(np.array(area_fwd_new))]

plt.figure(figsize=(4,4))
plt.boxplot(area_back_nan, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_forward_nan, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull')
plt.title('Agulhas - Area convex hull \n (1000 back/fwd runs)', fontsize=14)

plt.ylim([-1e7,1e8])
# Out:
# (-10000000.0, 100000000.0)

# %%
plt.figure(figsize=(16,4))
plt.scatter(range(len(sepdis_fwd_new)),sepdis_fwd_new, color='blue')
plt.scatter(range(len(sepdis_back_new)),sepdis_back_new, color='red')
plt.title('Seperation distance', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Seperation distance')

# %%
dif = np.array(sepdis_back_new) - np.array(sepdis_fwd_new)
ldif = range(len(dif))
meandif = np.nanmean(dif)

plt.figure(figsize=(16,4))
for i in range(len(dif)):
    if dif[i]>0:
        plt.scatter(ldif[i], dif[i], color='green')
    else:
        plt.scatter(ldif[i], dif[i], color='red')

plt.axhline(y=0, color='black')
plt.axhline(meandif, color='grey', linestyle='--')
plt.ylim([-12500, 12500])
plt.title('Seperation distance', fontsize=24)
# Out:
# Text(0.5, 1.0, 'Seperation distance')

# %%
sepdis_back_new_nan = np.array(sepdis_back_new)[~np.isnan(np.array(sepdis_back_new))]
sepdis_fwd_new_nan = np.array(sepdis_fwd_new)[~np.isnan(np.array(sepdis_fwd_new))]

plt.figure(figsize=(4,4))
plt.boxplot(sepdis_back_new_nan, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sepdis_fwd_new_nan, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Sep. dist.')
plt.title('Agulhas - Seperation distance\n (1000 back/fwd runs)', fontsize=14)

plt.ylim([-1000,15000])
# Out:
# (-1000.0, 15000.0)

# %%
n_nan = np.array(n)[~np.isnan(np.array(n))]
n_nan = n_nan[n_nan<450]
np.mean(n_nan)
# Out:
# 6.327552986512524

# %%
plt.figure(figsize=(16,4))
plt.scatter(range(len(n)),n)
plt.ylim([0,27])
# Out:
# (0.0, 27.0)

# %%
import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from matplotlib.lines import Line2D

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)

fwd.traj.plot(linewidth=0.1, color='grey')
    
plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()
