# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import pandas as pd
import xarray as xr
import trajan as ta
from scipy.signal import get_window

# %% [markdown]
# ## Import data

# %%
area_forward3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward3.out')
area_back3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back3.out')

area_forward4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward4.out')
area_back4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back4.out')

area_forward6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward6.out')
area_back6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back6.out')

area_forward7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward7.out')
area_back7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back7.out')

area_forward8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward8.out')
area_back8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back8.out')

area_forward10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward10.out')
area_back10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back10.out')

# %%
area_forward = np.concatenate([area_forward3,area_forward4,area_forward6,area_forward7,area_forward8,area_forward10])
area_back = np.concatenate([area_back3,area_back4,area_back6,area_back7,area_back8,area_back10])

# %%
area_back = np.array(area_back)[~np.isnan(np.array(area_back))]
area_forward = np.array(area_forward)[~np.isnan(np.array(area_forward))]

# %%
sd_forward3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd3.out')
sd_back3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back3.out')

sd_forward4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd4.out')
sd_back4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back4.out')

sd_forward6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd6.out')
sd_back6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back6.out')

sd_forward7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd7.out')
sd_back7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back7.out')

sd_forward8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd8.out')
sd_back8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back8.out')

sd_forward10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd10.out')
sd_back10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back10.out')

sd_forward = np.concatenate([sd_forward3, sd_forward4,sd_forward6,sd_forward7,sd_forward8,sd_forward10])
sd_back = np.concatenate([sd_back3,sd_back4,sd_back6,sd_back7,sd_back8,sd_back10])

sd_back = np.array(sd_back)[~np.isnan(np.array(sd_back))]
sd_forward = np.array(sd_forward)[~np.isnan(np.array(sd_forward))]

# %%
plt.figure(figsize=(13,6))

plt.subplot(1,2,1)
plt.boxplot(area_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull', fontsize=14)
plt.ylim([-0.05e8,1.02e8])
plt.title('Area Convex Hull', fontsize=20)

plt.subplot(1,2,2)
plt.boxplot(sd_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Sep. dist. (m)', fontsize=14)
plt.title('Separation Distance', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Separation Distance')

# %%
plt.figure(figsize=(4,4))
plt.boxplot(area_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull')
plt.ylim([0,0.5e8])
plt.title('All drifters')
# Out:
# Text(0.5, 1.0, 'All drifters')

# %% [markdown]
# ## Conditions

# %% [markdown]
# ## Regions

# %% [markdown]
# ### Agulhas Current

# %%
area_agulhas_fwd = []
area_agulhas_back = []
sd_agulhas_fwd = []
sd_agulhas_back = []
for i in range(0,20,1):
    area_agulhas_fwd.append(area_forward3[i])
    area_agulhas_fwd.append(area_forward4[i])
    area_agulhas_back.append(area_back3[i])
    area_agulhas_back.append(area_back4[i])
    sd_agulhas_fwd.append(sd_forward3[i])
    sd_agulhas_fwd.append(sd_forward4[i])
    sd_agulhas_back.append(sd_back3[i])
    sd_agulhas_back.append(sd_back4[i])
for i in range(0,2,1):
    area_agulhas_fwd.append(area_forward8[i])
    area_agulhas_fwd.append(area_forward10[i])
    area_agulhas_back.append(area_back8[i])
    area_agulhas_back.append(area_back10[i])
    sd_agulhas_fwd.append(sd_forward8[i])
    sd_agulhas_fwd.append(sd_forward10[i])
    sd_agulhas_back.append(sd_back8[i])
    sd_agulhas_back.append(sd_back10[i])
    
area_agulhas_back = np.array(area_agulhas_back)[~np.isnan(np.array(area_agulhas_back))]
area_agulhas_fwd = np.array(area_agulhas_fwd)[~np.isnan(np.array(area_agulhas_fwd))]
sd_agulhas_back = np.array(sd_agulhas_back)[~np.isnan(np.array(sd_agulhas_back))]
sd_agulhas_fwd = np.array(sd_agulhas_fwd)[~np.isnan(np.array(sd_agulhas_fwd))]

# %%
plt.figure(figsize=(13,6))

plt.subplot(1,2,1)
plt.boxplot(area_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull', fontsize=14)
plt.title('Agulhas Current - Area Convex Hull', fontsize=20)

plt.subplot(1,2,2)
plt.boxplot(sd_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Sep. dist. (m)', fontsize=14)
plt.title('Separation Distance', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Separation Distance')

# %% [markdown]
# ### Retroflection

# %%
retro_fwd = []
retro_back = []
sd_retro_fwd = []
sd_retro_back =[]
for i in range(21,56,1):
    retro_fwd.append(area_forward3[i])
    retro_fwd.append(area_forward4[i])
    retro_back.append(area_back3[i])
    retro_back.append(area_back4[i])
    sd_retro_fwd.append(sd_forward3[i])
    sd_retro_fwd.append(sd_forward4[i])
    sd_retro_back.append(sd_back3[i])
    sd_retro_back.append(sd_back4[i])
for i in range(3,18,1):
    retro_fwd.append(area_forward8[i])
    retro_fwd.append(area_forward10[i])
    retro_back.append(area_back8[i])
    retro_back.append(area_back10[i])
    sd_retro_fwd.append(sd_forward8[i])
    sd_retro_fwd.append(sd_forward10[i])
    sd_retro_back.append(sd_back8[i])
    sd_retro_back.append(sd_back10[i])

retro_back = np.array(retro_back)[~np.isnan(np.array(retro_back))]
retro_fwd = np.array(retro_fwd)[~np.isnan(np.array(retro_fwd))]
sd_retro_back = np.array(sd_retro_back)[~np.isnan(np.array(sd_retro_back))]
sd_retro_fwd = np.array(sd_retro_fwd)[~np.isnan(np.array(sd_retro_fwd))]

# %%
plt.figure(figsize=(13,6))

plt.subplot(1,2,1)
plt.boxplot(retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull', fontsize=14)
plt.title('Retroflection - Area Convex Hull', fontsize=20)
plt.ylim([-0.05e8,1.02e8])

plt.subplot(1,2,2)
plt.boxplot(sd_retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Sep. dist. (m)', fontsize=14)
plt.title('Separation Distance', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Separation Distance')

# %% [markdown]
# ### Return Current

# %%
return_fwd = []
return_back = []
for i in range(57,74,1):
    return_fwd.append(area_forward3[i])
    return_back.append(area_back3[i])
for i in range(97,119,1):
    return_fwd.append(area_forward6[i])
    return_back.append(area_back6[i])
for i in range(18,103,1):
    return_fwd.append(area_forward8[i])
    return_back.append(area_back8[i])
for i in range(18,115,1): 
    return_fwd.append(area_forward10[i])
    return_back.append(area_back10[i])
    
return_back = np.array(return_back)[~np.isnan(np.array(return_back))]
return_fwd = np.array(return_fwd)[~np.isnan(np.array(return_fwd))]

# %%
plt.figure(figsize=(4,4))
plt.boxplot(return_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(return_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull')
plt.ylim([0,0.5e8])
plt.title('Return Cur.')
# Out:
# Text(0.5, 1.0, 'Return Cur.')

# %% [markdown]
# ### Eddies

# %%
ed_fwd = []
ed_back = []
for i in range(60,126,1):
    ed_fwd.append(area_forward3[i])
    ed_back.append(area_back3[i])      
for i in range(0,96,1):
    ed_fwd.append(area_forward6[i])
    ed_back.append(area_back6[i])

ed_fwd.append(area_forward7[i])
ed_back.append(area_back7[i])

ed_back = np.array(ed_back)[~np.isnan(np.array(ed_back))]
ed_fwd = np.array(ed_fwd)[~np.isnan(np.array(ed_fwd))]

# %%
plt.figure(figsize=(4,4))
plt.boxplot(ed_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(ed_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull')
plt.ylim([0,0.5e8])
plt.title('Eddies')
# Out:
# Text(0.5, 1.0, 'Eddies')
