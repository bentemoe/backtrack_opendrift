# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import pandas as pd
import xarray as xr
import trajan as ta
from scipy.signal import get_window

# %% [markdown]
# ## Import data

# %%
area_forward3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward3.out')
area_back3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back3.out')

area_forward4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward4.out')
area_back4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back4.out')

area_forward6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward6.out')
area_back6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back6.out')

area_forward7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward7.out')
area_back7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back7.out')

area_forward8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward8.out')
area_back8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back8.out')

area_forward10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_forward10.out')
area_back10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/area_back10.out')

# %%
area_forward = np.concatenate([area_forward3,area_forward4,area_forward6,area_forward7,area_forward8,area_forward10])
area_back = np.concatenate([area_back3,area_back4,area_back6,area_back7,area_back8,area_back10])

# %%
area_back = np.array(area_back)[~np.isnan(np.array(area_back))]
area_forward = np.array(area_forward)[~np.isnan(np.array(area_forward))]

# %%
sd_forward3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd3.out')
sd_back3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back3.out')

sd_forward4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd4.out')
sd_back4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back4.out')

sd_forward6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd6.out')
sd_back6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back6.out')

sd_forward7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd7.out')
sd_back7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back7.out')

sd_forward8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd8.out')
sd_back8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back8.out')

sd_forward10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_fwd10.out')
sd_back10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/agulhas_oceandrift_48h/sepdis_back10.out')

sd_forward = np.concatenate([sd_forward3, sd_forward4,sd_forward6,sd_forward7,sd_forward8,sd_forward10])
sd_back = np.concatenate([sd_back3,sd_back4,sd_back6,sd_back7,sd_back8,sd_back10])

sd_back = np.array(sd_back)[~np.isnan(np.array(sd_back))]
sd_forward = np.array(sd_forward)[~np.isnan(np.array(sd_forward))]

# %%
msd_forward3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_fwd3.out')
msd_back3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_back3.out')

msd_forward4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_fwd4.out')
msd_back4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_back4.out')

msd_forward6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_fwd6.out')
msd_back6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_back6.out')

msd_forward7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_fwd7.out')
msd_back7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_back7.out')

msd_forward8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_fwd8.out')
msd_back8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_back8.out')

msd_forward10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_fwd10.out')
msd_back10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/msd_back10.out')

msd_forward = np.concatenate([msd_forward3, msd_forward4,msd_forward6,msd_forward7,msd_forward8,msd_forward10])
msd_back = np.concatenate([msd_back3,msd_back4,msd_back6,msd_back7,msd_back8,msd_back10])

msd_back = np.array(msd_back)[~np.isnan(np.array(msd_back))]
msd_forward = np.array(msd_forward)[~np.isnan(np.array(msd_forward))]

# %%
dist_forward3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_fwd3.out')
dist_back3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_back3.out')

dist_forward4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_fwd4.out')
dist_back4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_back4.out')

dist_forward6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_fwd6.out')
dist_back6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_back6.out')

dist_forward7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_fwd7.out')
dist_back7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_back7.out')

dist_forward8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_fwd8.out')
dist_back8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_back8.out')

dist_forward10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_fwd10.out')
dist_back10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/dist_back10.out')

dist_forward = np.concatenate([dist_forward3, dist_forward4,dist_forward6,dist_forward7,dist_forward8,dist_forward10])
dist_back = np.concatenate([dist_back3,dist_back4,dist_back6,dist_back7,dist_back8,dist_back10])

dist_back = np.array(dist_back)[~np.isnan(np.array(dist_back))]
dist_forward = np.array(dist_forward)[~np.isnan(np.array(dist_forward))]

# %%
n3 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/n3.out')
n4 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/n4.out')
n6 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/n6.out')
n7 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/n7.out')
n8 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/n8.out')
n10 = np.loadtxt('C:/Users/bente/Documents/BACKTRACK/backtracking/agulhas_opendrift_48h_sd_of_hits/n10.out')

n = np.concatenate([n3,n4,n6,n7,n8,n10])
n = np.array(n)[~np.isnan(np.array(n))]

# %% [markdown]
# ## All drifters

# %%
plt.boxplot(n)
plt.ylim([-1, 10])
# Out:
# (-1.0, 10.0)

# %%
np.min(n)
# Out:
# 0.0

# %%
np.max(n)
# Out:
# 10.0

# %%
np.mean(n)
# Out:
# 6.0424143556280585

# %%
np.median(n)
# Out:
# 6.0

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.boxplot(area_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull', fontsize=14)
plt.title('Area Convex Hull', fontsize=20)

plt.subplot(1,3,2)
plt.boxplot(sd_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Sep. dist. (m)', fontsize=14)
plt.title('Centroid - Observed drifter', fontsize=20)

plt.subplot(1,3,3)
plt.boxplot(msd_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Mean sep. dist. (m)', fontsize=14)
plt.title('Centroid - Start location', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Centroid - Start location')

# %%
plt.figure(figsize=(14,14))

plt.subplot(2,2,1)
plt.boxplot(area_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.8e8])
plt.title('Spread: Area', fontsize=28)
plt.grid()

plt.subplot(2,2,3)
plt.boxplot(sd_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.title('Accuracy: Centroid', fontsize=28)
plt.ylim([-4000,120000])
plt.grid()

plt.subplot(2,2,2)
plt.boxplot(msd_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Spread: Centroid', fontsize=28)
plt.ylim([-400,16000])
plt.grid()

plt.subplot(2,2,4)
plt.boxplot(dist_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(dist_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.title('Accuracy: All points', fontsize=28)
plt.ylim([-4000,120000])
plt.grid()

# %%
plt.figure(figsize=(21,6))

plt.subplot(1,3,2)
plt.boxplot(area_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.7e8])
plt.title('Area Convex Hull', fontsize=22)
plt.grid()

plt.subplot(1,3,1)
plt.boxplot(sd_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.ylim([-4000,115000])
plt.title('Centroid - Observed drifter', fontsize=22)
plt.grid()

plt.subplot(1,3,3)
plt.boxplot(msd_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Centroid - Start location', fontsize=22)
plt.ylim([0,15000])
plt.grid()

# %%
plt.figure(figsize=(4,4))
plt.boxplot(area_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_forward, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'])
plt.ylabel('Area convex hull')
plt.ylim([0,0.5e8])
plt.title('All drifters')
# Out:
# Text(0.5, 1.0, 'All drifters')

# %% [markdown]
# ## Conditions

# %% [markdown]
# ## Regions

# %% [markdown]
# ### Agulhas Current

# %%
area_agulhas_fwd = []
area_agulhas_back = []
sd_agulhas_fwd = []
sd_agulhas_back = []
msd_agulhas_fwd = []
msd_agulhas_back = []
dist_agulhas_fwd = []
dist_agulhas_back = []
for i in range(0,20,1):
    area_agulhas_fwd.append(area_forward3[i])
    area_agulhas_fwd.append(area_forward4[i])
    area_agulhas_back.append(area_back3[i])
    area_agulhas_back.append(area_back4[i])
    sd_agulhas_fwd.append(sd_forward3[i])
    sd_agulhas_fwd.append(sd_forward4[i])
    sd_agulhas_back.append(sd_back3[i])
    sd_agulhas_back.append(sd_back4[i])
    msd_agulhas_fwd.append(msd_forward3[i])
    msd_agulhas_fwd.append(msd_forward4[i])
    msd_agulhas_back.append(msd_back3[i])
    msd_agulhas_back.append(msd_back4[i])
    dist_agulhas_fwd.append(dist_forward3[i])
    dist_agulhas_fwd.append(dist_forward4[i])
    dist_agulhas_back.append(dist_back3[i])
    dist_agulhas_back.append(dist_back4[i])
for i in range(0,2,1):
    area_agulhas_fwd.append(area_forward8[i])
    area_agulhas_fwd.append(area_forward10[i])
    area_agulhas_back.append(area_back8[i])
    area_agulhas_back.append(area_back10[i])
    sd_agulhas_fwd.append(sd_forward8[i])
    sd_agulhas_fwd.append(sd_forward10[i])
    sd_agulhas_back.append(sd_back8[i])
    sd_agulhas_back.append(sd_back10[i])
    msd_agulhas_fwd.append(msd_forward8[i])
    msd_agulhas_fwd.append(msd_forward10[i])
    msd_agulhas_back.append(msd_back8[i])
    msd_agulhas_back.append(msd_back10[i])
    dist_agulhas_fwd.append(dist_forward8[i])
    dist_agulhas_fwd.append(dist_forward10[i])
    dist_agulhas_back.append(dist_back8[i])
    dist_agulhas_back.append(dist_back10[i])
    
area_agulhas_back = np.array(area_agulhas_back)[~np.isnan(np.array(area_agulhas_back))]
area_agulhas_fwd = np.array(area_agulhas_fwd)[~np.isnan(np.array(area_agulhas_fwd))]
sd_agulhas_back = np.array(sd_agulhas_back)[~np.isnan(np.array(sd_agulhas_back))]
sd_agulhas_fwd = np.array(sd_agulhas_fwd)[~np.isnan(np.array(sd_agulhas_fwd))]
msd_agulhas_back = np.array(msd_agulhas_back)[~np.isnan(np.array(msd_agulhas_back))]
msd_agulhas_fwd = np.array(msd_agulhas_fwd)[~np.isnan(np.array(msd_agulhas_fwd))]
dist_agulhas_back = np.array(dist_agulhas_back)[~np.isnan(np.array(dist_agulhas_back))]
dist_agulhas_fwd = np.array(dist_agulhas_fwd)[~np.isnan(np.array(dist_agulhas_fwd))]

# %%
plt.figure(figsize=(14,14))

plt.subplot(2,2,1)
plt.boxplot(area_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.7e8])
plt.title('Spread - Area', fontsize=22)
plt.grid()

plt.subplot(2,2,3)
plt.boxplot(sd_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.title('Accuracy - Centroid', fontsize=22)
plt.ylim([-4000,120000])
plt.grid()

plt.subplot(2,2,2)
plt.boxplot(msd_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Spread - Centroid', fontsize=22)
plt.ylim([0,15000])
plt.grid()

plt.subplot(2,2,4)
plt.boxplot(dist_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(dist_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.title('Accuracy - All points', fontsize=22)
plt.ylim([-4000,120000])
plt.grid()

# %%
plt.figure(figsize=(21,6))

plt.subplot(1,3,1)
plt.boxplot(area_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(area_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.7e8])
plt.title('Area Convex Hull', fontsize=22)
plt.grid()

plt.subplot(1,3,2)
plt.boxplot(sd_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.ylim([-4000,115000])
plt.title('Centroid - Observed drifter', fontsize=22)
plt.grid()

plt.subplot(1,3,3)
plt.boxplot(msd_agulhas_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_agulhas_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Centroid - Start location', fontsize=22)
plt.ylim([0,15000])
plt.grid()

# %% [markdown]
# ### Retroflection

# %%
retro_fwd = []
retro_back = []
sd_retro_fwd = []
sd_retro_back = []
msd_retro_fwd = []
msd_retro_back = []
dist_retro_fwd = []
dist_retro_back = []
for i in range(21,56,1):
    retro_fwd.append(area_forward3[i])
    retro_fwd.append(area_forward4[i])
    retro_back.append(area_back3[i])
    retro_back.append(area_back4[i])
    sd_retro_fwd.append(sd_forward3[i])
    sd_retro_fwd.append(sd_forward4[i])
    sd_retro_back.append(sd_back3[i])
    sd_retro_back.append(sd_back4[i])
    msd_retro_fwd.append(msd_forward3[i])
    msd_retro_fwd.append(msd_forward4[i])
    msd_retro_back.append(msd_back3[i])
    msd_retro_back.append(msd_back4[i])
    dist_retro_fwd.append(dist_forward3[i])
    dist_retro_fwd.append(dist_forward4[i])
    dist_retro_back.append(dist_back3[i])
    dist_retro_back.append(dist_back4[i])
for i in range(3,18,1):
    retro_fwd.append(area_forward8[i])
    retro_fwd.append(area_forward10[i])
    retro_back.append(area_back8[i])
    retro_back.append(area_back10[i])
    sd_retro_fwd.append(sd_forward8[i])
    sd_retro_fwd.append(sd_forward10[i])
    sd_retro_back.append(sd_back8[i])
    sd_retro_back.append(sd_back10[i])
    msd_retro_fwd.append(msd_forward8[i])
    msd_retro_fwd.append(msd_forward10[i])
    msd_retro_back.append(msd_back8[i])
    msd_retro_back.append(msd_back10[i])
    dist_retro_fwd.append(dist_forward8[i])
    dist_retro_fwd.append(dist_forward10[i])
    dist_retro_back.append(dist_back8[i])
    dist_retro_back.append(dist_back10[i])

retro_back = np.array(retro_back)[~np.isnan(np.array(retro_back))]
retro_fwd = np.array(retro_fwd)[~np.isnan(np.array(retro_fwd))]
sd_retro_back = np.array(sd_retro_back)[~np.isnan(np.array(sd_retro_back))]
sd_retro_fwd = np.array(sd_retro_fwd)[~np.isnan(np.array(sd_retro_fwd))]
msd_retro_back = np.array(msd_retro_back)[~np.isnan(np.array(msd_retro_back))]
msd_retro_fwd = np.array(msd_retro_fwd)[~np.isnan(np.array(msd_retro_fwd))]
dist_retro_back = np.array(dist_retro_back)[~np.isnan(np.array(dist_retro_back))]
dist_retro_fwd = np.array(dist_retro_fwd)[~np.isnan(np.array(dist_retro_fwd))]

# %%
plt.figure(figsize=(14,14))

plt.subplot(2,2,1)
plt.boxplot(retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.7e8])
plt.title('Spread - Area', fontsize=22)
plt.grid()

plt.subplot(2,2,3)
plt.boxplot(sd_retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.title('Accuracy - Centroid', fontsize=22)
plt.ylim([-4000,120000])
plt.grid()

plt.subplot(2,2,2)
plt.boxplot(msd_retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Spread - Centroid', fontsize=22)
plt.ylim([0,15000])
plt.grid()

plt.subplot(2,2,4)
plt.boxplot(dist_retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(dist_retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.title('Accuracy - All points', fontsize=22)
plt.ylim([-4000,120000])
plt.grid()

# %%
plt.figure(figsize=(21,6))

plt.subplot(1,3,1)
plt.boxplot(retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.7e8])
plt.title('Area Convex Hull', fontsize=22)
plt.grid()

plt.subplot(1,3,2)
plt.boxplot(sd_retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.ylim([-4000,115000])
plt.title('Centroid - Observed drifter', fontsize=22)
plt.grid()

plt.subplot(1,3,3)
plt.boxplot(msd_retro_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_retro_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Centroid - Start location', fontsize=22)
plt.ylim([0,15000])
plt.grid()

# %% [markdown]
# ### Return Current

# %%
return_fwd = []
return_back = []
sd_return_fwd = []
sd_return_back = []
msd_return_fwd = []
msd_return_back = []
for i in range(57,74,1):
    return_fwd.append(area_forward3[i])
    return_back.append(area_back3[i])
    sd_return_fwd.append(sd_forward3[i])
    sd_return_back.append(sd_back3[i])
    msd_return_fwd.append(msd_forward3[i])
    msd_return_back.append(msd_back3[i])
for i in range(97,119,1):
    return_fwd.append(area_forward6[i])
    return_back.append(area_back6[i])
    sd_return_fwd.append(sd_forward6[i])
    sd_return_back.append(sd_back6[i])
    msd_return_fwd.append(msd_forward6[i])
    msd_return_back.append(msd_back6[i])
for i in range(18,103,1):
    return_fwd.append(area_forward8[i])
    return_back.append(area_back8[i])
    sd_return_fwd.append(sd_forward8[i])
    sd_return_back.append(sd_back8[i])
    msd_return_fwd.append(msd_forward8[i])
    msd_return_back.append(msd_back8[i])
for i in range(18,115,1): 
    return_fwd.append(area_forward10[i])
    return_back.append(area_back10[i])
    sd_return_fwd.append(sd_forward10[i])
    sd_return_back.append(sd_back10[i])
    msd_return_fwd.append(msd_forward10[i])
    msd_return_back.append(msd_back10[i])
    
return_back = np.array(return_back)[~np.isnan(np.array(return_back))]
return_fwd = np.array(return_fwd)[~np.isnan(np.array(return_fwd))]
sd_return_back = np.array(sd_return_back)[~np.isnan(np.array(sd_return_back))]
sd_return_fwd = np.array(sd_return_fwd)[~np.isnan(np.array(sd_return_fwd))]
msd_return_back = np.array(msd_return_back)[~np.isnan(np.array(msd_return_back))]
msd_return_fwd = np.array(msd_return_fwd)[~np.isnan(np.array(msd_return_fwd))]

# %%
plt.figure(figsize=(21,6))

plt.subplot(1,3,1)
plt.boxplot(return_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(return_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.7e8])
plt.title('Area Convex Hull', fontsize=22)
plt.grid()

plt.subplot(1,3,2)
plt.boxplot(sd_return_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_return_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.ylim([-4000,115000])
plt.title('Centroid - Observed drifter', fontsize=22)
plt.grid()

plt.subplot(1,3,3)
plt.boxplot(msd_return_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_return_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Centroid - Start location', fontsize=22)
plt.ylim([0,15000])
plt.grid()

# %% [markdown]
# ### Eddies

# %%
ed_fwd = []
ed_back = []
sd_ed_fwd = []
sd_ed_back = []
msd_ed_fwd = []
msd_ed_back = []
for i in range(60,126,1):
    ed_fwd.append(area_forward3[i])
    ed_back.append(area_back3[i])
    sd_ed_fwd.append(sd_forward3[i])
    sd_ed_back.append(sd_back3[i])
    msd_ed_fwd.append(msd_forward3[i])
    msd_ed_back.append(msd_back3[i])
for i in range(0,96,1):
    ed_fwd.append(area_forward6[i])
    ed_back.append(area_back6[i])
    sd_ed_fwd.append(sd_forward6[i])
    sd_ed_back.append(sd_back6[i])
    msd_ed_fwd.append(msd_forward6[i])
    msd_ed_back.append(msd_back6[i])

ed_fwd.append(area_forward7[i])
ed_back.append(area_back7[i])
sd_ed_fwd.append(sd_forward7[i])
sd_ed_back.append(sd_back7[i])
msd_ed_fwd.append(msd_forward7[i])
msd_ed_back.append(msd_back7[i])

ed_back = np.array(ed_back)[~np.isnan(np.array(ed_back))]
ed_fwd = np.array(ed_fwd)[~np.isnan(np.array(ed_fwd))]
sd_ed_back = np.array(sd_ed_back)[~np.isnan(np.array(sd_ed_back))]
sd_ed_fwd = np.array(sd_ed_fwd)[~np.isnan(np.array(sd_ed_fwd))]
msd_ed_back = np.array(msd_ed_back)[~np.isnan(np.array(msd_ed_back))]
msd_ed_fwd = np.array(msd_ed_fwd)[~np.isnan(np.array(msd_ed_fwd))]

# %%
plt.figure(figsize=(21,6))

plt.subplot(1,3,1)
plt.boxplot(ed_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(ed_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Area convex hull', fontsize=18)
plt.ylim([-0.03e8,0.7e8])
plt.title('Area Convex Hull', fontsize=22)
plt.grid()

plt.subplot(1,3,2)
plt.boxplot(sd_ed_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(sd_ed_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Sep. dist. (m)', fontsize=18)
plt.ylim([-4000,115000])
plt.title('Centroid - Observed drifter', fontsize=22)
plt.grid()

plt.subplot(1,3,3)
plt.boxplot(msd_ed_back, positions=[2], patch_artist=True, boxprops=dict(facecolor='red', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.boxplot(msd_ed_fwd, positions=[1], patch_artist=True, boxprops=dict(facecolor='blue', alpha=0.8), medianprops=dict(color='black', linewidth=2), widths = 0.5)
plt.xticks([1,2],['forward', 'backward'], fontsize=16)
plt.ylabel('Mean sep. dist. (m)', fontsize=18)
plt.title('Centroid - Start location', fontsize=22)
plt.ylim([0,15000])
plt.grid()
