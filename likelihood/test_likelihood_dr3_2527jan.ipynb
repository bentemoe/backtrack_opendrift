# %%
import os
os.path

from datetime import datetime, timedelta
import cmocean

import pyproj
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import trajan as ta
import pandas as pd

import opendrift
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.physics_methods import wind_drift_factor_from_trajectory, distance_between_trajectories, skillscore_liu_weissberg

import cartopy.crs as ccrs
from matplotlib.lines import Line2D

from scipy.spatial import ConvexHull, convex_hull_plot_2d

import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from matplotlib.lines import Line2D

# %%
d03 = xr.open_dataset('C:/Users/bente/Documents/BACKTRACK/backtracking/data/OO-2023.nc')       # all drifter data
d03 = d03.traj.gridtime('1H')
d03 = d03.isel(trajectory=0)             # drifter OO-2023-03

# %%
startlat = d03.lat.sel(time=slice(datetime(2023, 1, 27, 3, 12, 8), datetime(2023, 1, 27, 3, 12, 8))).values
startlon = d03.lon.sel(time=slice(datetime(2023, 1, 27, 3, 12, 8), datetime(2023, 1, 27, 3, 12, 8))).values

# %%
len(hits[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(hits[0])
#
# NameError: name 'hits' is not defined

# %%
reader_globcur = reader_netCDF_CF_generic.Reader("C:/Users/bente/Documents/THESIS/Globcurrent/*.nc")

# %%
duration = timedelta(hours=48)                # 2 days
start_time = datetime(2023,1,25,3,12,8)
end_time = start_time + duration

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/bwd19210.nc"

# %%
orev = OceanDrift(loglevel=50)
orev.add_reader([reader_globcur])
orev.set_config('drift:advection_scheme', 'runge-kutta4')
orev.seed_elements(lon=startlon, lat=startlat, radius=10000, radius_type='uniform', number=192, time=end_time)
orev.run(duration=duration, time_step=-900, time_step_output=3600, outfile=outfile_bwd)

# %%
back192 = xr.open_dataset(outfile_bwd)

# %%
diflon = np.max(back.isel(time=48).lon.values) - np.min(back.isel(time=48).lon.values)
diflat = np.max(back.isel(time=48).lat.values) - np.min(back.isel(time=48).lat.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 diflon = np.max(back.isel(time=48).lon.values) - np.min(back.isel(time=48).lon.values)
#       2 diflat = np.max(back.isel(time=48).lat.values) - np.min(back.isel(time=48).lat.values)
#
# NameError: name 'back' is not defined

# %%
diflat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 diflat
#
# NameError: name 'diflat' is not defined

# %%
# Define domain of possible origin !!! WITH RANDOM UNIFORM SEEDING !!!
lons = np.zeros((120,120))
lats = np.zeros((120,120))
for j in range(120):
    lons[j] = np.random.uniform(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 120) # Much coarser CCC
    lats[j] = np.random.uniform(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 120)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 lats = np.zeros((120,120))
#       4 for j in range(120):
# ----> 5     lons[j] = np.random.uniform(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 120) # Much coarser CCC
#       6     lats[j] = np.random.uniform(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 120)
#
# NameError: name 'back' is not defined

# %%
np.min(back.lat.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 np.min(back.lat.values)
#
# NameError: name 'back' is not defined

# %%
np.max(back.lat.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.max(back.lat.values)
#
# NameError: name 'back' is not defined

# %%
outfile = "D:/backtrack/oceandrift_48h/likelihood/fwd9.nc"

# %%
ofwd = OceanDrift(loglevel=50)
ofwd.add_reader([reader_globcur])
ofwd.set_config('drift:advection_scheme', 'runge-kutta4')
ofwd.seed_elements(lon=lons, lat=lats, radius=0, time=start_time)
ofwd.run(duration=duration, time_step=900, time_step_output=3600, outfile=outfile)
# Out:
# 16:02:59 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.

# %%
fwd = xr.open_dataset(outfile)

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)

fwd.traj.plot(linewidth=0.1)

back.traj.plot(linewidth=0.1,color='red')

d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-27 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
dist2incident[dist2incident<10000]
# Out:
# array([5028.00809472, 4688.68788335, 7905.15312876, 5891.5463524 ,
#        3866.90912946, 8717.73211363, 7141.30695791, 9048.00094068,
#        5728.84795734, 8125.10195308, 7877.41334095, 7044.27432243,
#        8184.44568084, 9808.85016798, 9227.19309886, 2971.0090503 ,
#        3041.42533862,  913.14082689, 6858.03473312, 7808.19116952,
#        6040.39398029, 9009.39967656, 7195.23513436, 9842.59681574,
#        7585.93426309, 8785.70845796, 6183.37583745, 8866.28583918,
#        6401.84314631, 6067.70583993, 6070.35382087, 5287.98156052,
#        6706.62317321, 1378.83430398, 7274.53658875, 7776.62102227,
#        9459.92251283, 5338.58451887, 7226.13032519, 5202.74813362,
#        9125.35054705, 9824.58275561, 4971.74704887, 5630.79117601,
#        7237.95837471, 9215.64867685, 8615.0842864 , 2989.68712619,
#        4007.44850114, 5008.88833112, 8933.97064365, 5581.39905864,
#        2931.9694212 , 8796.5288493 , 7825.93677374, 3556.24499477,
#        6303.84040323, 9145.00409856, 9588.17966027, 8442.49184513,
#        5242.72951297, 7105.93168647, 4563.83906912, 7819.54203099,
#        6397.71750638, 7230.56432947, 5954.35863701, 9539.93022843,
#        4182.64817496, 8104.75821576, 7943.78209039, 2092.56567985,
#        4590.00127272, 4375.44948639, 7410.46323738, 9104.39044274,
#        6212.90417494, 7490.11931191, 6781.58086738, 4209.70017883,
#        2282.8418509 , 9039.32796557, 1770.56777117, 3530.18675429,
#        7386.88070841, 8601.84333409, 6178.09635247, 8860.36971506,
#        7971.87340975, 6979.8211628 , 8867.75477843, 6201.2277538 ,
#        4103.6995643 , 1834.16271934, 8424.80636237, 5712.83899185,
#        5338.65254461,  408.52722078, 7617.28839004, 8920.10987786,
#        9006.6401682 , 5579.79529231, 7688.78859722, 9334.09878314,
#        3151.99811168, 7863.62042417, 7456.98863409, 7487.64462487,
#        6234.078153  , 4051.95668541,  876.38211852, 7575.13735891,
#        8840.1160024 , 2411.6602174 , 4950.1657974 , 4311.14915621,
#        8961.59429832, 6378.05370248, 7286.56260839, 9156.65629593,
#        9404.49154549, 3385.3724055 , 4768.73706251, 9722.93789201,
#        2087.5206239 , 3737.27239007, 2101.3699825 , 5598.42995739,
#        4106.54680012, 8952.90299494, 4464.68715341, 7667.41115148,
#        7172.13310474, 6426.80437665, 8514.99255222, 6226.17677721,
#        7554.92403497, 4568.28077428, 8623.48432339, 6762.46546014,
#        9805.72867186, 8403.38785825, 2240.41771889, 9585.07303163,
#        8253.15818781, 6469.30174289, 2300.38868979, 5010.97679363,
#        9671.87298491, 9492.96205724, 5589.88120453, 8615.97870623,
#        7433.42692906, 7247.35134319, 8853.88868431, 8814.06065726,
#        7064.26345357, 4226.53157407, 8962.47193054, 8312.3196725 ,
#        4788.03601797, 9321.77851876, 9749.53907685, 8607.83105822,
#        3961.2593239 , 6008.80304475, 6067.64551777, 2673.31802756,
#        6867.4873652 , 5545.46663861, 7474.92403695, 6814.92948324,
#        7733.0379121 , 4817.76500267, 9116.56766291, 9879.00651888,
#        9798.93396109, 4909.80682963, 6098.87202809, 9329.07568322,
#        6729.01659291, 7379.29155059, 3095.61063004, 2068.76328717,
#        6250.8590064 , 6773.71576621, 7756.40637091, 7836.89103926,
#        3801.35080128, 4341.12390378, 7440.54754196, 3333.19133218])

# %%
ilat = d03.lat.sel(time=slice(datetime(2023, 1, 27, 3, 12, 8), datetime(2023, 1, 27, 3, 12, 8))).values
ilon = d03.lon.sel(time=slice(datetime(2023, 1, 27, 3, 12, 8), datetime(2023, 1, 27, 3, 12, 8))).values

# %%
dist2incident<5000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dist2incident<5000
#
# NameError: name 'dist2incident' is not defined

# %%
## FORWARD ## 
lon0 = []
lat0 = []
lonend0 = []
latend0 = []
for j in range(len(fwd.trajectory)):
        ### calculating hits ###
        lon0.append(fwd.isel(trajectory=j).lon.values)
        lat0.append(fwd.isel(trajectory=j).lat.values)
        lonend0.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
        latend0.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
        
geod = pyproj.Geod(ellps='WGS84')
on = np.ones(len(lonend0))
dummy1, dummy2, dist2incident = geod.inv(lonend0, latend0, ilon*on, ilat*on)
hits = np.where(dist2incident<10000)

hit_start_lons0= []
hit_start_lats0= []
for m in range(len(hits)):
        hit_start_lons0.append(lon0[hits[0][m]][0])
        hit_start_lats0.append(lat0[hits[0][m]][0])

# %%
### PLOT ### 
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)

for i in range(len(fwd.trajectory)):
    fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
    
for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

# for i in range(len(fwd.trajectory)):
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-27 03:12:08')).traj.plot(color='black')  

custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='grey', lw=4),
                Line2D([0], [0], color='black', lw=4)]

ax.legend(custom_lines, ['Fwd - Elements hitting target','Backward traj.', 'Fwd - Elements NOT hitting target', 'Observed drifter trajectory'])

plt.gca().autoscale()
plt.title('Opendrift Leeway - 25-01-2023 03:12 to 27-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
np.where(dist2incident<5000)
# Out:
# (array([   98,   312,  1485,  1505,  1557,  2629,  3201,  3500,  3518,
#          3865,  3887,  4492,  4725,  5121,  5150,  5155,  5433,  5435,
#          5485,  5615,  6311,  6343,  6483,  7204,  7580,  7628,  8355,
#          8482,  8484,  8887,  8953,  9044,  9202,  9285,  9353,  9553,
#         10326, 10898, 11052, 11788, 12101, 12407, 12747, 13104, 13493,
#         13866, 13878, 14213, 14245, 14286], dtype=int64),)

# %%
hits[0]
# Out:
# array([   17,    98,   125,   129,   312,   534,   543,   615,   884,
#          957,  1010,  1130,  1286,  1402,  1471,  1485,  1505,  1557,
#         1626,  1846,  1853,  1926,  1933,  2174,  2184,  2275,  2327,
#         2333,  2510,  2536,  2560,  2611,  2616,  2629,  2716,  2764,
#         2871,  2875,  2908,  3045,  3155,  3195,  3201,  3316,  3350,
#         3400,  3419,  3500,  3518,  3530,  3752,  3779,  3865,  3868,
#         3884,  3887,  4009,  4142,  4151,  4184,  4224,  4358,  4492,
#         4523,  4533,  4680,  4687,  4721,  4725,  4804,  4862,  5121,
#         5150,  5155,  5262,  5287,  5380,  5420,  5424,  5433,  5435,
#         5479,  5485,  5615,  5651,  5718,  5819,  5888,  5952,  5969,
#         6102,  6291,  6311,  6343,  6358,  6417,  6465,  6483,  6536,
#         6624,  6695,  6912,  6974,  7150,  7204,  7218,  7368,  7406,
#         7476,  7580,  7628,  8124,  8195,  8355,  8482,  8484,  8599,
#         8638,  8731,  8793,  8872,  8887,  8953,  8982,  9044,  9202,
#         9285,  9292,  9353,  9366,  9553,  9555,  9590,  9835,  9842,
#         9912, 10185, 10326, 10415, 10492, 10640, 10774, 10898, 10902,
#        10944, 11042, 11052, 11128, 11157, 11199, 11236, 11336, 11400,
#        11541, 11555, 11620, 11675, 11788, 12085, 12100, 12101, 12173,
#        12238, 12293, 12407, 12441, 12586, 12747, 12750, 12762, 12800,
#        13070, 13082, 13104, 13149, 13217, 13243, 13493, 13587, 13629,
#        13660, 13758, 13866, 13878, 13879, 14003, 14048, 14087, 14213,
#        14245, 14261, 14286], dtype=int64)

# %%
len(hits[0])
# Out:
# 192

# %%
o_hit = opendrift.open(outfile, elements=hits[0])
# Out:
# 11:00:42 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 11:00:42 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 11:00:42 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 11:00:42 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 11:00:42 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 11:00:42 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 11:00:42 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/fwd9.nc
# 11:00:43 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 11:00:43 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 11:00:43 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_hit.plot()
# Out:
# 11:00:45 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=False, lscale=None
# 11:00:46 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (18.257474517822267, 21.474693679809572, -38.867324066162105, -37.0016143798828)..
# 11:01:00 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (18.257474517822267, 21.474693679809572, -38.867324066162105, -37.0016143798828)..
# 11:01:01 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (18.257474517822267, 21.474693679809572, -38.867324066162105, -37.0016143798828)..
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-27 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x808.791 with 1 Axes>)

# %%
of = opendrift.open_xarray(outfile)
density_fwd = of.get_histogram(pixelsize_m=5000).isel(time=0).isel(origin_marker=0)
density_fwd = density_fwd.where(density_fwd>0)
density_fwd = density_fwd/density_fwd.sum()*100
vmax = density_fwd.max()
o_hit.plot(background=density_fwd, clabel='Probability of origin [%]', fast=True, markersize=.5, lalpha=.02, vmin=0)
# Out:
# 11:01:17 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 11:01:17 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 11:01:17 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 11:01:17 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 11:01:17 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 11:01:17 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 11:01:17 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 11:01:17 DEBUG   opendrift.export.io_netcdf:216: Importing with Xarray from D:/backtrack/oceandrift_48h/likelihood/fwd9.nc
# 11:01:17 INFO    opendrift:118: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object
# 11:01:18 INFO    opendrift.models.basemodel:4646: 	calculating for origin_marker 0...
# 11:01:18 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 11:01:18 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-27 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x808.791 with 2 Axes>)

# %%
density_forwards.isel(lon_bin=40).isel(lat_bin=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 density_forwards.isel(lon_bin=40).isel(lat_bin=40)
#
# NameError: name 'density_forwards' is not defined

# %%
lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
#       2 latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)
#
# NameError: name 'back' is not defined

# %%
fwd = xr.open_dataset(outfile)

# %%
xfwd = fwd.isel(trajectory=hits[0])

# %% [markdown]
# #### Start lon and lat of FWD 'hits'

# %%
lon = []       # lon for 'hits'
lat = []       # lat for 'hits'

for i in range(len(xfwd.trajectory)):
    lon.append(xfwd.isel(trajectory=i).lon.values[0])
    lat.append(xfwd.isel(trajectory=i).lat.values[0])

# %% [markdown]
# #### Start lon and lat of all FWD runs

# %%
lonall = []
latall = []

for i in range(len(fwd.trajectory)):
    lonall.append(fwd.isel(trajectory=i).lon.values[0])
    latall.append(fwd.isel(trajectory=i).lat.values[0])

# %%
# Set the desired grid size
grid_size_lon = 0.120  # Change this to your desired grid size
grid_size_lat = 0.100

# Calculate the number of grid cells in each dimension
lon_bins = np.arange(np.min(lonall), np.max(lonall) + grid_size_lon, grid_size_lon)
lat_bins = np.arange(np.min(latall), np.max(latall) + grid_size_lat, grid_size_lat)

# %%
def count_points_in_grid(lon, lat, lonbins, latbins):
    
    lobi = []
    labi = []
    for i in range(len(lonbins)-1):
        lobi.append((lonbins[i]+lonbins[i+1])/2)
    for i in range(len(latbins)-1):
        labi.append((latbins[i]+latbins[i+1])/2)
        
    # Count the number of points in each grid cell
    counts, xedges, yedges = np.histogram2d(lon, lat, bins=[lonbins, latbins])
    
    # Create a new DataArray with the counts and assign coordinates
    counts_dataarray = xr.DataArray(counts, coords=[('lon_bin', lobi), ('lat_bin', labi)])
    
    return counts_dataarray 

# Call the function to count points in grid cells
grid_counts = count_points_in_grid(lon, lat, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 13:51:06 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:51:06 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-27 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x808.791 with 2 Axes>)

# %%
# Call the function to count points in grid cells
grid_counts_all = count_points_in_grid(lonall, latall, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts_all, clabel='$N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 13:50:49 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:50:49 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-27 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x808.791 with 2 Axes>)

# %%
o_hit.plot(background=grid_counts/grid_counts_all, clabel='$n_j / N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 13:50:40 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:50:40 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-27 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x808.791 with 2 Axes>)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.pcolormesh(grid_counts_all)

# %%
lonback = []       # lon for bwd
latback = []       # lat for bwd

for i in range(len(back192.trajectory)):
    lonback.append(back192.isel(trajectory=i).lon.values[-1])
    latback.append(back192.isel(trajectory=i).lat.values[-1])

# %%
grid_counts_back = count_points_in_grid(lonback, latback, lon_bins, lat_bins)

# %%
o_back = opendrift.open(outfile_bwd)
# Out:
# 13:41:49 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 13:41:49 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 13:41:49 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 13:41:49 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 13:41:49 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 13:41:49 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 13:41:49 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 13:41:49 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/bwd19210.nc
# 13:41:49 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 13:41:49 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 13:41:49 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_back.plot(background=grid_counts_back, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 13:50:20 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:50:20 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-27 03:12 to 2023-01-25 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x809.621 with 2 Axes>)

# %%
fig = plt.figure(1, figsize=(12,10))
ax = fig.add_subplot(111, projection=ccrs.Mercator())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')

back192.traj.plot(linewidth=0.5,color='red')

# ax.plot(back192.isel(time=0).lon.values, back192.isel(time=0).lat.values, 'ro', markersize=0.5, transform=ccrs.Geodetic())
# for i in hits: 
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', markersize=0.5, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-27 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
o_hit.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=-1, vmax=3)
# Out:
# 13:41:55 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:41:55 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-27 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x808.791 with 2 Axes>)

# %%
o_hit.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 13:45:24 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:45:24 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-27 03:12 UTC (49 steps)'}>,
#  <Figure size 1100x808.791 with 2 Axes>)
