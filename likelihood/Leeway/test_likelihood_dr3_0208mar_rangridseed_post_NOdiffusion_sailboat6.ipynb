# %%
import os
os.path

from datetime import datetime, timedelta
import cmocean

import pyproj
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import trajan as ta
import pandas as pd

import opendrift
from opendrift.models.leeway import Leeway
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.physics_methods import wind_drift_factor_from_trajectory, distance_between_trajectories, skillscore_liu_weissberg

import cartopy.crs as ccrs
from matplotlib.lines import Line2D

from scipy.spatial import ConvexHull, convex_hull_plot_2d

import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from matplotlib.lines import Line2D

# %%
d03 = xr.open_dataset('C:/Users/bente/Documents/BACKTRACK/backtracking/data/OO-2023.nc')       # all drifter data
d03 = d03.traj.gridtime('1H')
d03 = d03.isel(trajectory=0)             # drifter OO-2023-03

# %%
startlat = d03.lat.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values
startlon = d03.lon.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values

# %%
len(hits[0])
# Out:
# 30

# %%
reader_globcur = reader_netCDF_CF_generic.Reader("C:/Users/bente/Documents/THESIS/Globcurrent/*.nc")
reader_wind = reader_netCDF_CF_generic.Reader('C:/Users/bente/Documents/THESIS/Globcurrent/Simulations_24h/OO-2023-03/agulhas_wind_2023.nc',
        standard_name_mapping={'u10': 'x_wind',
                               'v10': 'y_wind'})

object_type = 62  # 78 = Sewage floatables; downwind 1.8 percent wdf; no offset but stdev around 3 cm/s; right/left slope 0.16 percent

# %%
duration = timedelta(hours=144)                # 6 days
start_time = datetime(2023,3,2,3,12,8)
end_time = start_time + duration

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/lw_bwd0511mar_sailb30.nc"

# %%
orev = Leeway(loglevel=50)
orev.add_reader([reader_globcur, reader_wind])
orev.set_config('drift:advection_scheme', 'runge-kutta4')
#orev.set_config('drift:horizontal_diffusivity', 20)
orev.seed_elements(lon=startlon, lat=startlat, radius=10000, radius_type='uniform', number=30, time=end_time, object_type=object_type)
orev.run(duration=duration, time_step=-900, time_step_output=3600, outfile=outfile_bwd)

# %%
back = xr.open_dataset(outfile_bwd)

# %%
# diflon = np.max(back.isel(time=120).lon.values) - np.min(back.isel(time=120).lon.values)
# diflat = np.max(back.isel(time=120).lat.values) - np.min(back.isel(time=120).lat.values)

# %%
end_time
# Out:
# datetime.datetime(2023, 3, 8, 3, 12, 8)

# %%
# # Define domain of possible origin !!! WITH RANDOM UNIFORM SEEDING !!!
# lons = np.zeros((120,120))
# lats = np.zeros((120,120))
# for j in range(120):
#     lons[j] = np.random.uniform(np.min(back.isel(time=120).lon.values)-(0.5), np.max(back.isel(time=120).lon.values)+(0.5), 120) # Much coarser CCC
#     lats[j] = np.random.uniform(np.min(back.isel(time=120).lat.values)-(0.5), np.max(back.isel(time=120).lat.values)+(0.5), 120)

# %%
np.min(back.lat.values)
# Out:
# -38.2613

# %%
np.max(back.lat.values)
# Out:
# -32.971294

# %%
# Set the desired grid size
grid_size_lon = 0.360  # Change this to your desired grid size
grid_size_lat = 0.300

# Calculate the number of grid cells in each dimension
lon_bins = np.arange(np.min(back.isel(time=120).lon.values)-(0.5), np.max(back.isel(time=120).lon.values)+(0.5), grid_size_lon)
lat_bins = np.arange(np.min(back.isel(time=120).lat.values)-(0.5), np.max(back.isel(time=120).lat.values)+(0.5), grid_size_lat)

# %%
binmesh = np.meshgrid(lon_bins, lat_bins)

# %%
lons = np.zeros((len(lon_bins)-1,(len(lat_bins)*100)-100))
lats = np.zeros((len(lon_bins)-1,(len(lat_bins)*100)-100))
for i in range(len(binmesh[0][0])-1):
    for j in range(len(binmesh[1])-1):
        lons[i][(j*100):((j+1)*100)] = np.random.uniform(binmesh[0][0][i], binmesh[0][0][i+1], 100) # Much coarser CCC
        lats[i][(j*100):((j+1)*100)] = np.random.uniform(binmesh[1][j][0], binmesh[1][j+1][0], 100)

# %% [markdown]
# # FWD

# %%
outfile = "D:/backtrack/oceandrift_48h/likelihood/lw_fwd0511mar_nodif_sailb.nc"

# %%
ofwd = Leeway(loglevel=50)
ofwd.add_reader([reader_globcur, reader_wind])
ofwd.set_config('drift:advection_scheme', 'runge-kutta4')
#ofwd.set_config('drift:horizontal_diffusivity', 20)
ofwd.seed_elements(lon=lons, lat=lats, radius=0, time=start_time, object_type=object_type)
ofwd.run(duration=duration, time_step=900, time_step_output=3600, outfile=outfile)

# %%
fwd = xr.open_dataset(outfile)

# %%
fwd.trajectory
# Out:
# <xarray.DataArray 'trajectory' (trajectory: 24000)>
# array([    1,     2,     3, ..., 23998, 23999, 24000])
# Coordinates:
#   * trajectory  (trajectory) int32 1 2 3 4 5 6 ... 23996 23997 23998 23999 24000
# Attributes:
#     cf_role:  trajectory_id
#     units:    1

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)

#fwd.traj.plot(linewidth=0.1)

for i in range(len(fwd.trajectory)):
    ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

#back.traj.plot(linewidth=0.1,color='red')

#d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-30 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
ilat = d03.lat.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values
ilon = d03.lon.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values

# %%
## FORWARD ## 
lon0 = []
lat0 = []
lonend0 = []
latend0 = []
for j in range(len(fwd.trajectory)):
        ### calculating hits ###
        lon0.append(fwd.isel(trajectory=j).lon.values)
        lat0.append(fwd.isel(trajectory=j).lat.values)
        lonend0.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
        latend0.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
        
geod = pyproj.Geod(ellps='WGS84')
on = np.ones(len(lonend0))
dummy1, dummy2, dist2incident = geod.inv(lonend0, latend0, ilon*on, ilat*on)
hits = np.where(dist2incident<10000)

hit_start_lons0= []
hit_start_lats0= []
for m in range(len(hits)):
        hit_start_lons0.append(lon0[hits[0][m]][0])
        hit_start_lats0.append(lat0[hits[0][m]][0])

# %%
len(hits[0])
# Out:
# 30

# %%
### PLOT ### 
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)

for i in range(len(fwd.trajectory)):
    fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
    
for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

# for i in range(len(fwd.trajectory)):
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-03-05 03:12:08', '2023-03-11 03:12:08')).traj.plot(color='black')  

custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='grey', lw=4),
                Line2D([0], [0], color='black', lw=4)]

ax.legend(custom_lines, ['Fwd - Elements hitting target','Backward traj.', 'Fwd - Elements NOT hitting target', 'Observed drifter trajectory'])

plt.gca().autoscale()
plt.title('Opendrift Leeway - 25-01-2023 03:12 to 27-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
len(fwd.trajectory)
# Out:
# 24000

# %%
len(hits[0])
# Out:
# 30

# %%
o_hit = opendrift.open(outfile, elements=hits[0])
# Out:
# 12:57:10 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 12:57:10 DEBUG   opendrift.models.basemodel:618: Adding 4 config items from basemodel
# 12:57:10 DEBUG   opendrift.models.basemodel:618: Adding 10 config items from basemodel
# 12:57:10 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 12:57:10 DEBUG   opendrift.models.basemodel:618: Adding 2 config items from leeway
# 12:57:10 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:jibe_probability
# 12:57:10 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/lw_fwd0511mar_nodif_sailb.nc
# 12:57:12 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 10.0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> 60.0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:jibe_probability -> 0.04
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 12:57:12 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:object_type -> Person-in-water (PIW), unknown state (mean values)
# 12:57:12 INFO    opendrift:78: Returning <class 'opendrift.models.leeway.Leeway'> object

# %%
o_hit.plot()
# Out:
# 12:57:12 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=False, lscale=None
# 12:57:13 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (26.714044189453123, 31.825817489624026, -38.11348266601562, -33.22136764526366)..
# 12:57:21 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (26.714044189453123, 31.825817489624026, -38.11348266601562, -33.22136764526366)..
# 12:57:21 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (26.714044189453123, 31.825817489624026, -38.11348266601562, -33.22136764526366)..
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 933.782x1100 with 1 Axes>)

# %%
of = opendrift.open_xarray(outfile)
density_fwd = of.get_histogram(pixelsize_m=5000).isel(time=0).isel(origin_marker=0)
density_fwd = density_fwd.where(density_fwd>0)
density_fwd = density_fwd/density_fwd.sum()*100
vmax = density_fwd.max()
o_hit.plot(background=density_fwd, clabel='Probability of origin [%]', fast=True, markersize=.5, lalpha=.02, vmin=0)
# Out:
# 13:28:58 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 13:28:58 DEBUG   opendrift.models.basemodel:618: Adding 4 config items from basemodel
# 13:28:58 DEBUG   opendrift.models.basemodel:618: Adding 10 config items from basemodel
# 13:28:58 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 13:28:58 DEBUG   opendrift.models.basemodel:618: Adding 2 config items from leeway
# 13:28:58 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:jibe_probability
# 13:28:58 DEBUG   opendrift.export.io_netcdf:216: Importing with Xarray from D:/backtrack/oceandrift_48h/likelihood/lw_fwd0511mar_nodif.nc
# 13:28:58 INFO    opendrift:118: Returning <class 'opendrift.models.leeway.Leeway'> object
# 13:28:58 INFO    opendrift.models.basemodel:4646: 	calculating for origin_marker 0...
# 13:28:58 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:28:58 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SEWAGE)\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 730.039x1100 with 2 Axes>)

# %%
# lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
# latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)

# %%
fwd = xr.open_dataset(outfile)

# %%
xfwd = fwd.isel(trajectory=hits[0])

# %% [markdown]
# #### Start lon and lat of FWD 'hits'

# %%
lon = []       # lon for 'hits'
lat = []       # lat for 'hits'

for i in range(len(xfwd.trajectory)):
    lon.append(xfwd.isel(trajectory=i).lon.values[0])
    lat.append(xfwd.isel(trajectory=i).lat.values[0])

# %% [markdown]
# #### Start lon and lat of all FWD runs

# %%
lonall = []
latall = []

for i in range(len(fwd.trajectory)):
    lonall.append(fwd.isel(trajectory=i).lon.values[0])
    latall.append(fwd.isel(trajectory=i).lat.values[0])

# %%
# # Set the desired grid size
# grid_size_lon = 0.080  # Change this to your desired grid size
# grid_size_lat = 0.070

# # Calculate the number of grid cells in each dimension
# lon_bins = np.arange(np.min(lonall), np.max(lonall) + grid_size_lon, grid_size_lon)
# lat_bins = np.arange(np.min(latall), np.max(latall) + grid_size_lat, grid_size_lat)

# %%
def count_points_in_grid(lon, lat, lonbins, latbins):
    
    lobi = []
    labi = []
    for i in range(len(lonbins)-1):
        lobi.append((lonbins[i]+lonbins[i+1])/2)
    for i in range(len(latbins)-1):
        labi.append((latbins[i]+latbins[i+1])/2)
        
    # Count the number of points in each grid cell
    counts, xedges, yedges = np.histogram2d(lon, lat, bins=[lonbins, latbins])
    
    # Create a new DataArray with the counts and assign coordinates
    counts_dataarray = xr.DataArray(counts, coords=[('lon_bin', lobi), ('lat_bin', labi)])
    
    return counts_dataarray 

# Call the function to count points in grid cells
grid_counts = count_points_in_grid(lon, lat, lon_bins, lat_bins)

# %%
lat_bins
# Out:
# array([-38.21722412, -37.91722412, -37.61722412, -37.31722412,
#        -37.01722412, -36.71722412, -36.41722412, -36.11722412,
#        -35.81722412, -35.51722412, -35.21722412, -34.91722412,
#        -34.61722412, -34.31722412, -34.01722412, -33.71722412,
#        -33.41722412])

# %%
len(lon_bins)
# Out:
# 16

# %%
o_hit.plot(background=grid_counts, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 12:59:16 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 12:59:16 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 933.782x1100 with 2 Axes>)

# %%
# Call the function to count points in grid cells
grid_counts_all = count_points_in_grid(lonall, latall, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts_all, clabel='$N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 12:59:24 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 12:59:24 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 933.782x1100 with 2 Axes>)

# %%
o_hit.plot(background=grid_counts/grid_counts_all, clabel='$n_j / N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 12:59:27 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 12:59:27 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 933.782x1100 with 2 Axes>)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.pcolormesh(grid_counts_all)

# %%
likelihood = grid_counts/grid_counts_all

# %%
likelihood.plot(x=grid_counts.dims[0], y=grid_counts.dims[1], cmap='YlOrRd')
plt.title('likelihood: nj/Nj')
plt.grid()

# %% [markdown]
# ### Equal Prior Probability

# %%
prior = grid_counts_all/len(fwd.trajectory)

# %% [markdown]
# ### Variable Prior Probability

# %% [markdown]
# Variable prior by LATITUDE:

# %%
varprior1 = (grid_counts_all[:,0:3]-4)
varprior2 = (grid_counts_all[:,3:7]+7)
varprior3 = (grid_counts_all[:,7:11]-4)

# %%
varprior = xr.concat([varprior1, varprior2,varprior3], dim='lat_bin')/len(fwd.trajectory)

# %% [markdown]
# Variable prior by LONGITUDE:

# %%
len(grid_counts[6:12])
# Out:
# 6

# %%
varprior1 = (grid_counts_all[0:6]+6) 
varprior2 = (grid_counts_all[6:12]-6)

# %%
varprior = xr.concat([varprior1, varprior2], dim='lon_bin')/len(fwd.trajectory)

# %% [markdown]
# Check if sum of all prior probabilities is 1!!!

# %%
np.sum(prior)
# Out:
# <xarray.DataArray ()>
# array(1.)

# %%
np.sum(varprior)
# Out:
# <xarray.DataArray ()>
# array(0.8)

# %% [markdown]
# ### Posterior (and norm. const.)

# %%
norm_const = len(hits[0])/len(fwd.trajectory)
posterior = (likelihood*prior)/norm_const

# %%
norm_const = len(hits[0])/len(fwd.trajectory)
varposterior = (likelihood*varprior)/norm_const

# %%
np.sum(posterior)
# Out:
# <xarray.DataArray ()>
# array(1.)

# %% [markdown]
# For equal prior:

# %%
posterior.plot(x=posterior.dims[0], y=posterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %% [markdown]
# For variable prior:

# %%
varprior.plot(x=varprior.dims[0], y=varprior.dims[1], cmap='YlOrRd')
plt.title('P(Aj): Prior probability')
plt.grid()

# %%
varposterior.plot(x=varposterior.dims[0], y=varposterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %%
o_hit.plot(posterior, clabel='Posterior Probability', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 13:02:18 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:02:18 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 933.782x1100 with 2 Axes>)

# %%
fig = plt.figure(1, figsize=(18,8))
ax = fig.add_subplot(111, projection=ccrs.PlateCarree())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

#posterior.plot.pcolormesh(x="lon_bin", y="lat_bin", ax=ax, cmap='YlOrRd', infer_intervals=True)

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.3, color='grey')
    ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=0.6, transform=ccrs.PlateCarree(), label='startloc. fwd OD simulations')

ax.plot(d03.sel(time=slice('2023-03-02 03:12:08', '2023-03-02 03:12:08')).lon.values, d03.sel(time=slice('2023-03-02 03:12:08', '2023-03-02 03:12:08')).lat.values, 'X', color='red', mec='black', markersize=14, transform=ccrs.PlateCarree(), label='startloc. observed drifter')  

post = posterior.plot.pcolormesh(x="lon_bin", y="lat_bin", ax=ax, cmap='YlOrRd', label='Posterior probability')
#fig.colorbar(post, ax=ax, location='right', label='Posterior')

plt.legend(fontsize=12, loc='upper left')
plt.gca().autoscale()
plt.title('Posterior Probability - Leeway: sailboat6 - 02-03-2023 03:12 to 08-03-2023 03:12 UTC', fontsize=12)
plt.show()

# %% [markdown]
# # BWD

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/lw_bwd0511mar_sailb30.nc"
back58 = xr.open_dataset(outfile_bwd)

# %%
lonback = []       # lon for bwd
latback = []       # lat for bwd

for i in range(len(back58.trajectory)):
    lonback.append(back58.isel(trajectory=i).lon.values[-1])
    latback.append(back58.isel(trajectory=i).lat.values[-1])

# %%
grid_counts_back = count_points_in_grid(lonback, latback, lon_bins, lat_bins)

# %%
o_back = opendrift.open(outfile_bwd)
# Out:
# 13:03:41 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 13:03:41 DEBUG   opendrift.models.basemodel:618: Adding 4 config items from basemodel
# 13:03:41 DEBUG   opendrift.models.basemodel:618: Adding 10 config items from basemodel
# 13:03:41 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 13:03:42 DEBUG   opendrift.models.basemodel:618: Adding 2 config items from leeway
# 13:03:42 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:jibe_probability
# 13:03:42 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/lw_bwd0511mar_sailb30.nc
# 13:03:42 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 10.0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> 60.0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:jibe_probability -> 0.04
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 13:03:42 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:object_type -> Person-in-water (PIW), unknown state (mean values)
# 13:03:42 INFO    opendrift:78: Returning <class 'opendrift.models.leeway.Leeway'> object

# %%
o_back.plot(background=grid_counts_back, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 13:03:44 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:03:44 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-08 03:12 to 2023-03-02 03:12 UTC (145 steps)'}>,
#  <Figure size 688.518x1100 with 2 Axes>)

# %%
grid_counts_back.plot(x=grid_counts_back.dims[0], y=grid_counts_back.dims[1], cmap='YlOrRd')
plt.title('Backwards nj')
plt.grid()

# %%
fig = plt.figure(1, figsize=(12,10))
ax = fig.add_subplot(111, projection=ccrs.Mercator())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')

back58.traj.plot(linewidth=0.5,color='red')

# ax.plot(back192.isel(time=0).lon.values, back192.isel(time=0).lat.values, 'ro', markersize=0.5, transform=ccrs.Geodetic())
# for i in hits: 
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', markersize=0.5, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-03-02 03:12:08', '2023-03-08 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
o_hit.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 13:04:00 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:04:00 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 933.782x1100 with 2 Axes>)

# %%
o_back.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 13:04:02 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 13:04:02 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - Leeway (SAILBOAT-6)\n2023-03-08 03:12 to 2023-03-02 03:12 UTC (145 steps)'}>,
#  <Figure size 688.518x1100 with 2 Axes>)
