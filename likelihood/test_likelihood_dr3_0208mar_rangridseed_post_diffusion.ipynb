# %%
import os
os.path

from datetime import datetime, timedelta
import cmocean

import pyproj
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import trajan as ta
import pandas as pd

import opendrift
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.physics_methods import wind_drift_factor_from_trajectory, distance_between_trajectories, skillscore_liu_weissberg

import cartopy.crs as ccrs
from matplotlib.lines import Line2D

from scipy.spatial import ConvexHull, convex_hull_plot_2d

import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from matplotlib.lines import Line2D

# %%
d03 = xr.open_dataset('C:/Users/bente/Documents/BACKTRACK/backtracking/data/OO-2023.nc')       # all drifter data
d03 = d03.traj.gridtime('1H')
d03 = d03.isel(trajectory=0)             # drifter OO-2023-03

# %%
startlat = d03.lat.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values
startlon = d03.lon.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values

# %%
len(hits[0])
# Out:
# 58

# %%
reader_globcur = reader_netCDF_CF_generic.Reader("C:/Users/bente/Documents/THESIS/Globcurrent/*.nc")

# %%
duration = timedelta(hours=144)                # 6 days
start_time = datetime(2023,3,2,3,12,8)
end_time = start_time + duration

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/bwd0511mar92.nc"

# %%
orev = OceanDrift(loglevel=50)
orev.add_reader([reader_globcur])
orev.set_config('drift:advection_scheme', 'runge-kutta4')
orev.set_config('drift:horizontal_diffusivity', 20)
orev.seed_elements(lon=startlon, lat=startlat, radius=10000, radius_type='uniform', number=58, time=end_time)
orev.run(duration=duration, time_step=-900, time_step_output=3600, outfile=outfile_bwd)
# Out:
# 13:19:05 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.

# %%
back = xr.open_dataset(outfile_bwd)

# %%
diflon = np.max(back.isel(time=120).lon.values) - np.min(back.isel(time=120).lon.values)
diflat = np.max(back.isel(time=120).lat.values) - np.min(back.isel(time=120).lat.values)

# %%
end_time
# Out:
# datetime.datetime(2023, 3, 8, 3, 12, 8)

# %%
# # Define domain of possible origin !!! WITH RANDOM UNIFORM SEEDING !!!
# lons = np.zeros((120,120))
# lats = np.zeros((120,120))
# for j in range(120):
#     lons[j] = np.random.uniform(np.min(back.isel(time=120).lon.values)-(0.5), np.max(back.isel(time=120).lon.values)+(0.5), 120) # Much coarser CCC
#     lats[j] = np.random.uniform(np.min(back.isel(time=120).lat.values)-(0.5), np.max(back.isel(time=120).lat.values)+(0.5), 120)

# %%
np.min(back.lat.values)
# Out:
# -36.701157

# %%
np.max(back.lat.values)
# Out:
# -35.101234

# %%
# Set the desired grid size
grid_size_lon = 0.360  # Change this to your desired grid size
grid_size_lat = 0.300

# Calculate the number of grid cells in each dimension
lon_bins = np.arange(np.min(back.isel(time=120).lon.values)-(0.5), np.max(back.isel(time=120).lon.values)+(0.5), grid_size_lon)
lat_bins = np.arange(np.min(back.isel(time=120).lat.values)-(0.5), np.max(back.isel(time=120).lat.values)+(0.5), grid_size_lat)

# %%
binmesh = np.meshgrid(lon_bins, lat_bins)

# %%
lons = np.zeros((len(lon_bins)-1,(len(lat_bins)*20)-20))
lats = np.zeros((len(lon_bins)-1,(len(lat_bins)*20)-20))
for i in range(len(binmesh[0][0])-1):
    for j in range(len(binmesh[1])-1):
        lons[i][(j*20):((j+1)*20)] = np.random.uniform(binmesh[0][0][i], binmesh[0][0][i+1], 20) # Much coarser CCC
        lats[i][(j*20):((j+1)*20)] = np.random.uniform(binmesh[1][j][0], binmesh[1][j+1][0], 20)

# %% [markdown]
# # FWD

# %%
outfile = "D:/backtrack/oceandrift_48h/likelihood/fwd0511mardif2.nc"

# %%
ofwd = OceanDrift(loglevel=50)
ofwd.add_reader([reader_globcur])
ofwd.set_config('drift:advection_scheme', 'runge-kutta4')
ofwd.set_config('drift:horizontal_diffusivity', 20)
ofwd.seed_elements(lon=lons, lat=lats, radius=0, time=start_time)
ofwd.run(duration=duration, time_step=900, time_step_output=3600, outfile=outfile)

# %%
fwd = xr.open_dataset(outfile)

# %%
fwd.trajectory
# Out:
# <xarray.DataArray 'trajectory' (trajectory: 3600)>
# array([   1,    2,    3, ..., 3598, 3599, 3600])
# Coordinates:
#   * trajectory  (trajectory) int32 1 2 3 4 5 6 ... 3595 3596 3597 3598 3599 3600
# Attributes:
#     cf_role:  trajectory_id
#     units:    1

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)

#fwd.traj.plot(linewidth=0.1)

for i in range(len(fwd.trajectory)):
    ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

#back.traj.plot(linewidth=0.1,color='red')

#d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-30 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 11
#       8 #fwd.traj.plot(linewidth=0.1)
#      10 for i in range(len(fwd.trajectory)):
# ---> 11     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#      13 #back.traj.plot(linewidth=0.1,color='red')
#      14
#      15 #d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-30 03:12:08')).traj.plot(color='black')
#      17 plt.gca().autoscale()
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\dataset.py:2920, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2918 var_indexers = {k: v for k, v in indexers.items() if k in var.dims}
#    2919 if var_indexers:
# -> 2920     var = var.isel(var_indexers)
#    2921     if drop and var.ndim == 0 and name in coord_names:
#    2922         coord_names.remove(name)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\variable.py:1135, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1132 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1134 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1135 return self[key]
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\variable.py:811, in Variable.__getitem__(self, key)
#     798 """Return a new Variable object whose contents are consistent with
#     799 getting the provided key from the underlying data.
#     800
#    (...)
#     808 array `x.values` directly.
#     809 """
#     810 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 811 data = as_indexable(self._data)[indexer]
#     812 if new_order:
#     813     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:703, in MemoryCachedArray.__getitem__(self, key)
#     702 def __getitem__(self, key):
# --> 703     return type(self)(_wrap_numpy_scalars(self.array[key]))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:670, in CopyOnWriteArray.__getitem__(self, key)
#     669 def __getitem__(self, key):
# --> 670     return type(self)(_wrap_numpy_scalars(self.array[key]))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:570, in LazilyIndexedArray.__getitem__(self, indexer)
#     568     array = LazilyVectorizedIndexedArray(self.array, self.key)
#     569     return array[indexer]
# --> 570 return type(self)(self.array, self._updated_key(indexer))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:536, in LazilyIndexedArray._updated_key(self, new_key)
#     534         full_key.append(k)
#     535     else:
# --> 536         full_key.append(_index_indexer_1d(k, next(iter_new_key), size))
#     537 full_key = tuple(full_key)
#     539 if all(isinstance(k, integer_types + (slice,)) for k in full_key):
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:288, in _index_indexer_1d(old_indexer, applied_indexer, size)
#     286         indexer = slice_slice(old_indexer, applied_indexer, size)
#     287     else:
# --> 288         indexer = _expand_slice(old_indexer, size)[applied_indexer]
#     289 else:
#     290     indexer = old_indexer[applied_indexer]
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:241, in _expand_slice(slice_, size)
#     240 def _expand_slice(slice_, size):
# --> 241     return np.arange(*slice_.indices(size))
#
# KeyboardInterrupt:

# %%
ilat = d03.lat.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values
ilon = d03.lon.sel(time=slice(datetime(2023, 3, 8, 3, 12, 8), datetime(2023, 3, 8, 3, 12, 8))).values

# %%
## FORWARD ## 
lon0 = []
lat0 = []
lonend0 = []
latend0 = []
for j in range(len(fwd.trajectory)):
        ### calculating hits ###
        lon0.append(fwd.isel(trajectory=j).lon.values)
        lat0.append(fwd.isel(trajectory=j).lat.values)
        lonend0.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
        latend0.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
        
geod = pyproj.Geod(ellps='WGS84')
on = np.ones(len(lonend0))
dummy1, dummy2, dist2incident = geod.inv(lonend0, latend0, ilon*on, ilat*on)
hits = np.where(dist2incident<10000)

hit_start_lons0= []
hit_start_lats0= []
for m in range(len(hits)):
        hit_start_lons0.append(lon0[hits[0][m]][0])
        hit_start_lats0.append(lat0[hits[0][m]][0])

# %%
hits
# Out:
# (array([1370, 1379, 1644, 1665, 1675, 1682, 1692, 1698, 1960, 1984, 1986,
#         1988, 1991, 1994, 1997, 2000, 2004, 2005, 2006, 2008, 2311, 2317,
#         2318, 2319, 2320, 2323, 2324, 2325, 2326, 2328, 2329, 2330, 2332,
#         2333, 2337, 2347, 2625, 2627, 2639, 2644, 2645, 2647, 2648, 2654,
#         2655, 2656, 2658, 2942, 2944, 2947, 2953, 2958, 2959, 2972, 2973,
#         2974, 2975, 2978], dtype=int64),)

# %%
### PLOT ### 
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)

for i in range(len(fwd.trajectory)):
    fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
    
for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

# for i in range(len(fwd.trajectory)):
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-03-05 03:12:08', '2023-03-11 03:12:08')).traj.plot(color='black')  

custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='grey', lw=4),
                Line2D([0], [0], color='black', lw=4)]

ax.legend(custom_lines, ['Fwd - Elements hitting target','Backward traj.', 'Fwd - Elements NOT hitting target', 'Observed drifter trajectory'])

plt.gca().autoscale()
plt.title('Opendrift Leeway - 25-01-2023 03:12 to 27-01-2023 03:12 UTC (49 steps)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 7
#       4 ax.gridlines(draw_labels=True)
#       6 for i in range(len(fwd.trajectory)):
# ----> 7     fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
#       9 # for i in hits:
#      10 #     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#      11 #     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#    (...)
#      15 #     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#      16 #     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())
#      18 d03.sel(time=slice('2023-03-05 03:12:08', '2023-03-11 03:12:08')).traj.plot(color='black')
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\dataset.py:2920, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2918 var_indexers = {k: v for k, v in indexers.items() if k in var.dims}
#    2919 if var_indexers:
# -> 2920     var = var.isel(var_indexers)
#    2921     if drop and var.ndim == 0 and name in coord_names:
#    2922         coord_names.remove(name)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\variable.py:1135, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1132 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1134 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1135 return self[key]
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\variable.py:811, in Variable.__getitem__(self, key)
#     798 """Return a new Variable object whose contents are consistent with
#     799 getting the provided key from the underlying data.
#     800
#    (...)
#     808 array `x.values` directly.
#     809 """
#     810 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 811 data = as_indexable(self._data)[indexer]
#     812 if new_order:
#     813     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:703, in MemoryCachedArray.__getitem__(self, key)
#     702 def __getitem__(self, key):
# --> 703     return type(self)(_wrap_numpy_scalars(self.array[key]))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:670, in CopyOnWriteArray.__getitem__(self, key)
#     669 def __getitem__(self, key):
# --> 670     return type(self)(_wrap_numpy_scalars(self.array[key]))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:570, in LazilyIndexedArray.__getitem__(self, indexer)
#     568     array = LazilyVectorizedIndexedArray(self.array, self.key)
#     569     return array[indexer]
# --> 570 return type(self)(self.array, self._updated_key(indexer))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:536, in LazilyIndexedArray._updated_key(self, new_key)
#     534         full_key.append(k)
#     535     else:
# --> 536         full_key.append(_index_indexer_1d(k, next(iter_new_key), size))
#     537 full_key = tuple(full_key)
#     539 if all(isinstance(k, integer_types + (slice,)) for k in full_key):
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:288, in _index_indexer_1d(old_indexer, applied_indexer, size)
#     286         indexer = slice_slice(old_indexer, applied_indexer, size)
#     287     else:
# --> 288         indexer = _expand_slice(old_indexer, size)[applied_indexer]
#     289 else:
#     290     indexer = old_indexer[applied_indexer]
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\xarray\core\indexing.py:241, in _expand_slice(slice_, size)
#     240 def _expand_slice(slice_, size):
# --> 241     return np.arange(*slice_.indices(size))
#
# KeyboardInterrupt:

# %%
len(fwd.trajectory)
# Out:
# 3600

# %%
len(hits[0])
# Out:
# 58

# %%
o_hit = opendrift.open(outfile, elements=hits[0])
# Out:
# 10:40:28 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 10:40:28 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 10:40:28 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 10:40:28 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 10:40:28 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 10:40:28 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 10:40:28 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 10:40:28 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/fwd0511mardif2.nc
# 10:40:29 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 20.0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 10:40:29 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 10:40:29 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_hit.plot()
# Out:
# 15:54:34 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=False, lscale=None
# 15:54:34 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (27.938336944580076, 29.47387733459473, -36.903464508056636, -34.93688659667968)..
# 15:54:36 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (27.938336944580076, 29.47387733459473, -36.903464508056636, -34.93688659667968)..
# 15:54:38 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (27.938336944580076, 29.47387733459473, -36.903464508056636, -34.93688659667968)..
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 695.568x1100 with 1 Axes>)

# %%
of = opendrift.open_xarray(outfile)
density_fwd = of.get_histogram(pixelsize_m=5000).isel(time=0).isel(origin_marker=0)
density_fwd = density_fwd.where(density_fwd>0)
density_fwd = density_fwd/density_fwd.sum()*100
vmax = density_fwd.max()
o_hit.plot(background=density_fwd, clabel='Probability of origin [%]', fast=True, markersize=.5, lalpha=.02, vmin=0)
# Out:
# 15:54:40 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 15:54:40 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 15:54:40 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 15:54:40 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 15:54:40 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 15:54:40 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 15:54:40 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 15:54:40 DEBUG   opendrift.export.io_netcdf:216: Importing with Xarray from D:/backtrack/oceandrift_48h/likelihood/fwd0511mardif2.nc
# 15:54:40 INFO    opendrift:118: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object
# 15:54:40 INFO    opendrift.models.basemodel:4646: 	calculating for origin_marker 0...
# 15:54:40 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 15:54:40 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 695.568x1100 with 2 Axes>)

# %%
# lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
# latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)

# %%
fwd = xr.open_dataset(outfile)

# %%
xfwd = fwd.isel(trajectory=hits[0])

# %% [markdown]
# #### Start lon and lat of FWD 'hits'

# %%
lon = []       # lon for 'hits'
lat = []       # lat for 'hits'

for i in range(len(xfwd.trajectory)):
    lon.append(xfwd.isel(trajectory=i).lon.values[0])
    lat.append(xfwd.isel(trajectory=i).lat.values[0])

# %% [markdown]
# #### Start lon and lat of all FWD runs

# %%
lonall = []
latall = []

for i in range(len(fwd.trajectory)):
    lonall.append(fwd.isel(trajectory=i).lon.values[0])
    latall.append(fwd.isel(trajectory=i).lat.values[0])

# %%
# # Set the desired grid size
# grid_size_lon = 0.080  # Change this to your desired grid size
# grid_size_lat = 0.070

# # Calculate the number of grid cells in each dimension
# lon_bins = np.arange(np.min(lonall), np.max(lonall) + grid_size_lon, grid_size_lon)
# lat_bins = np.arange(np.min(latall), np.max(latall) + grid_size_lat, grid_size_lat)

# %%
def count_points_in_grid(lon, lat, lonbins, latbins):
    
    lobi = []
    labi = []
    for i in range(len(lonbins)-1):
        lobi.append((lonbins[i]+lonbins[i+1])/2)
    for i in range(len(latbins)-1):
        labi.append((latbins[i]+latbins[i+1])/2)
        
    # Count the number of points in each grid cell
    counts, xedges, yedges = np.histogram2d(lon, lat, bins=[lonbins, latbins])
    
    # Create a new DataArray with the counts and assign coordinates
    counts_dataarray = xr.DataArray(counts, coords=[('lon_bin', lobi), ('lat_bin', labi)])
    
    return counts_dataarray 

# Call the function to count points in grid cells
grid_counts = count_points_in_grid(lon, lat, lon_bins, lat_bins)

# %%
lat_bins
# Out:
# array([-36.45102692, -36.15102692, -35.85102692, -35.55102692,
#        -35.25102692, -34.95102692])

# %%
len(lon_bins)
# Out:
# 5

# %%
o_hit.plot(background=grid_counts, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 10:40:46 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 10:40:46 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 695.568x1100 with 2 Axes>)

# %%
# Call the function to count points in grid cells
grid_counts_all = count_points_in_grid(lonall, latall, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts_all, clabel='$N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 10:40:51 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 10:40:51 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 695.568x1100 with 2 Axes>)

# %%
o_hit.plot(background=grid_counts/grid_counts_all, clabel='$n_j / N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 10:40:57 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 10:40:57 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 695.568x1100 with 2 Axes>)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.pcolormesh(grid_counts_all)

# %%
likelihood = grid_counts/grid_counts_all

# %%
likelihood.plot(x=grid_counts.dims[0], y=grid_counts.dims[1], cmap='YlOrRd')
plt.title('likelihood: nj/Nj')
plt.grid()

# %% [markdown]
# ### Equal Prior Probability

# %%
prior = grid_counts_all/len(fwd.trajectory)

# %% [markdown]
# ### Variable Prior Probability

# %% [markdown]
# Variable prior by LATITUDE:

# %%
varprior1 = (grid_counts_all[:,0:3]-4)
varprior2 = (grid_counts_all[:,3:7]+7)
varprior3 = (grid_counts_all[:,7:11]-4)

# %%
varprior = xr.concat([varprior1, varprior2,varprior3], dim='lat_bin')/len(fwd.trajectory)

# %% [markdown]
# Variable prior by LONGITUDE:

# %%
len(grid_counts[6:12])
# Out:
# 0

# %%
varprior1 = (grid_counts_all[0:6]+6) 
varprior2 = (grid_counts_all[6:12]-6)

# %%
varprior = xr.concat([varprior1, varprior2], dim='lon_bin')/len(fwd.trajectory)

# %% [markdown]
# Check if sum of all prior probabilities is 1!!!

# %%
np.sum(prior)
# Out:
# <xarray.DataArray ()>
# array(1.)

# %%
np.sum(varprior)
# Out:
# <xarray.DataArray ()>
# array(1.03333333)

# %% [markdown]
# ### Posterior (and norm. const.)

# %%
norm_const = len(hits[0])/len(fwd.trajectory)
posterior = (likelihood*prior)/norm_const

# %%
norm_const = len(hits[0])/len(fwd.trajectory)
varposterior = (likelihood*varprior)/norm_const

# %%
np.sum(posterior)
# Out:
# <xarray.DataArray ()>
# array(1.)

# %% [markdown]
# For equal prior:

# %%
posterior.plot(x=posterior.dims[0], y=posterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %% [markdown]
# For variable prior:

# %%
varprior.plot(x=varprior.dims[0], y=varprior.dims[1], cmap='YlOrRd')
plt.title('P(Aj): Prior probability')
plt.grid()

# %%
varposterior.plot(x=varposterior.dims[0], y=varposterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %%
o_hit.plot(posterior, clabel='Posterior Probability', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 10:41:43 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 10:41:43 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 695.568x1100 with 2 Axes>)

# %%
fig = plt.figure(1, figsize=(18,8))
ax = fig.add_subplot(111, projection=ccrs.PlateCarree())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

#posterior.plot.pcolormesh(x="lon_bin", y="lat_bin", ax=ax, cmap='YlOrRd', infer_intervals=True)

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.2, color='grey')
    ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=0.6, transform=ccrs.PlateCarree(), label='startloc. fwd OD simulations')

ax.plot(d03.sel(time=slice('2023-03-02 03:12:08', '2023-03-02 03:12:08')).lon.values, d03.sel(time=slice('2023-03-02 03:12:08', '2023-03-02 03:12:08')).lat.values, 'X', color='red', mec='black', markersize=14, transform=ccrs.PlateCarree(), label='startloc. observed drifter')  

post = posterior.plot.pcolormesh(x="lon_bin", y="lat_bin", ax=ax, cmap='YlOrRd', label='Posterior probability')
#fig.colorbar(post, ax=ax, location='right', label='Posterior')

plt.legend(fontsize=12, loc='upper left')
plt.gca().autoscale()
plt.title('Posterior Probability - Opendrift OceanDrift - 02-03-2023 03:12 to 08-03-2023 03:12 UTC', fontsize=12)
plt.show()

# %% [markdown]
# # BWD

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/bwd0511mar58.nc"
back58 = xr.open_dataset(outfile_bwd)

# %%
lonback = []       # lon for bwd
latback = []       # lat for bwd

for i in range(len(back58.trajectory)):
    lonback.append(back58.isel(trajectory=i).lon.values[-1])
    latback.append(back58.isel(trajectory=i).lat.values[-1])

# %%
grid_counts_back = count_points_in_grid(lonback, latback, lon_bins, lat_bins)

# %%
o_back = opendrift.open(outfile_bwd)
# Out:
# 17:14:37 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 17:14:37 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 17:14:37 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 17:14:37 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 17:14:37 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 17:14:37 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 17:14:37 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 17:14:37 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/bwd0511mar58.nc
# 17:14:37 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 20.0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 17:14:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 17:14:37 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_back.plot(background=grid_counts_back, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 17:14:37 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 17:14:37 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-08 03:12 to 2023-03-02 03:12 UTC (145 steps)'}>,
#  <Figure size 721.177x1100 with 2 Axes>)

# %%
grid_counts_back.plot(x=grid_counts_back.dims[0], y=grid_counts_back.dims[1], cmap='YlOrRd')
plt.title('Backwards nj')
plt.grid()

# %%
fig = plt.figure(1, figsize=(12,10))
ax = fig.add_subplot(111, projection=ccrs.Mercator())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')

back58.traj.plot(linewidth=0.5,color='red')

# ax.plot(back192.isel(time=0).lon.values, back192.isel(time=0).lat.values, 'ro', markersize=0.5, transform=ccrs.Geodetic())
# for i in hits: 
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', markersize=0.5, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-03-02 03:12:08', '2023-03-08 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
o_hit.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 17:14:41 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 17:14:41 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-02 03:12 to 2023-03-08 03:12 UTC (145 steps)'}>,
#  <Figure size 695.568x1100 with 2 Axes>)

# %%
o_back.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 17:14:42 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 17:14:42 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-03-08 03:12 to 2023-03-02 03:12 UTC (145 steps)'}>,
#  <Figure size 721.177x1100 with 2 Axes>)
