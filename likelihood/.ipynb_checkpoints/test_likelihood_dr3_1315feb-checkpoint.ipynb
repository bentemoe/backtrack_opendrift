# %%
import os
os.path

from datetime import datetime, timedelta
import cmocean

import pyproj
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import trajan as ta
import pandas as pd

import opendrift
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.physics_methods import wind_drift_factor_from_trajectory, distance_between_trajectories, skillscore_liu_weissberg

import cartopy.crs as ccrs
from matplotlib.lines import Line2D

from scipy.spatial import ConvexHull, convex_hull_plot_2d

import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from matplotlib.lines import Line2D

# %%
d03 = xr.open_dataset('C:/Users/bente/Documents/BACKTRACK/backtracking/data/OO-2023.nc')       # all drifter data
d03 = d03.traj.gridtime('1H')
d03 = d03.isel(trajectory=0)             # drifter OO-2023-03

# %%
startlat = d03.lat.sel(time=slice(datetime(2023, 2, 15, 3, 12, 8), datetime(2023, 2, 15, 3, 12, 8))).values
startlon = d03.lon.sel(time=slice(datetime(2023, 2, 15, 3, 12, 8), datetime(2023, 2, 15, 3, 12, 8))).values

# %%
len(hits[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(hits[0])
#
# NameError: name 'hits' is not defined

# %%
reader_globcur = reader_netCDF_CF_generic.Reader("C:/Users/bente/Documents/THESIS/Globcurrent/*.nc")

# %%
duration = timedelta(hours=48)                # 2 days
start_time = datetime(2023,2,13,3,12,8)
end_time = start_time + duration

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/bwd1315feb241.nc"

# %%
orev = OceanDrift(loglevel=50)
orev.add_reader([reader_globcur])
orev.set_config('drift:advection_scheme', 'runge-kutta4')
orev.seed_elements(lon=startlon, lat=startlat, radius=10000, radius_type='uniform', number=241, time=end_time)
orev.run(duration=duration, time_step=-900, time_step_output=3600, outfile=outfile_bwd)
# Out:
# 16:13:12 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.

# %%
back241 = xr.open_dataset(outfile_bwd)

# %%
diflon = np.max(back.isel(time=48).lon.values) - np.min(back.isel(time=48).lon.values)
diflat = np.max(back.isel(time=48).lat.values) - np.min(back.isel(time=48).lat.values)

# %%
diflat
# Out:
# 0.4349556

# %%
# Define domain of possible origin !!! WITH RANDOM UNIFORM SEEDING !!!
lons = np.zeros((120,120))
lats = np.zeros((120,120))
for j in range(120):
    lons[j] = np.random.uniform(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 120) # Much coarser CCC
    lats[j] = np.random.uniform(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 120)

# %%
np.min(back.lat.values)
# Out:
# -36.22217

# %%
np.max(back.lat.values)
# Out:
# -35.577347

# %%
outfile = "D:/backtrack/oceandrift_48h/likelihood/fwd1315feb.nc"

# %%
ofwd = OceanDrift(loglevel=50)
ofwd.add_reader([reader_globcur])
ofwd.set_config('drift:advection_scheme', 'runge-kutta4')
ofwd.seed_elements(lon=lons, lat=lats, radius=0, time=start_time)
ofwd.run(duration=duration, time_step=900, time_step_output=3600, outfile=outfile)

# %%
fwd = xr.open_dataset(outfile)

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)

fwd.traj.plot(linewidth=0.1)

back.traj.plot(linewidth=0.1,color='red')

d03.sel(time=slice('2023-02-13 03:12:08', '2023-02-15 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
ilat = d03.lat.sel(time=slice(datetime(2023, 2, 15, 3, 12, 8), datetime(2023, 2, 15, 3, 12, 8))).values
ilon = d03.lon.sel(time=slice(datetime(2023, 2, 15, 3, 12, 8), datetime(2023, 2, 15, 3, 12, 8))).values

# %%
## FORWARD ## 
lon0 = []
lat0 = []
lonend0 = []
latend0 = []
for j in range(len(fwd.trajectory)):
        ### calculating hits ###
        lon0.append(fwd.isel(trajectory=j).lon.values)
        lat0.append(fwd.isel(trajectory=j).lat.values)
        lonend0.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
        latend0.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
        
geod = pyproj.Geod(ellps='WGS84')
on = np.ones(len(lonend0))
dummy1, dummy2, dist2incident = geod.inv(lonend0, latend0, ilon*on, ilat*on)
hits = np.where(dist2incident<10000)

hit_start_lons0= []
hit_start_lats0= []
for m in range(len(hits)):
        hit_start_lons0.append(lon0[hits[0][m]][0])
        hit_start_lats0.append(lat0[hits[0][m]][0])

# %%
### PLOT ### 
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)

for i in range(len(fwd.trajectory)):
    fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
    
for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

# for i in range(len(fwd.trajectory)):
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-02-13 03:12:08', '2023-02-15 03:12:08')).traj.plot(color='black')  

custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='grey', lw=4),
                Line2D([0], [0], color='black', lw=4)]

ax.legend(custom_lines, ['Fwd - Elements hitting target','Backward traj.', 'Fwd - Elements NOT hitting target', 'Observed drifter trajectory'])

plt.gca().autoscale()
plt.title('Opendrift Leeway - 25-01-2023 03:12 to 27-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
o_hit = opendrift.open(outfile, elements=hits[0])
# Out:
# 13:58:44 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 13:58:44 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 13:58:44 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 13:58:44 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 13:58:44 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 13:58:44 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 13:58:44 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/fwd1315feb.nc
# 13:58:45 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 13:58:45 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 13:58:45 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_hit.plot()
# Out:
# 13:58:45 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=False, lscale=None
# 13:58:46 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (25.48539505004883, 26.58696212768555, -36.41947479248046, -35.37632446289062)..
# 13:59:02 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (25.48539505004883, 26.58696212768555, -36.41947479248046, -35.37632446289062)..
# 13:59:04 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: h, extent: (25.48539505004883, 26.58696212768555, -36.41947479248046, -35.37632446289062)..
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-13 03:12 to 2023-02-15 03:12 UTC (49 steps)'}>,
#  <Figure size 940.97x1100 with 1 Axes>)

# %%
of = opendrift.open_xarray(outfile)
density_fwd = of.get_histogram(pixelsize_m=5000).isel(time=0).isel(origin_marker=0)
density_fwd = density_fwd.where(density_fwd>0)
density_fwd = density_fwd/density_fwd.sum()*100
vmax = density_fwd.max()
o_hit.plot(background=density_fwd, clabel='Probability of origin [%]', fast=True, markersize=.5, lalpha=.02, vmin=0)
# Out:
# 16:04:16 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 16:04:16 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 16:04:16 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 16:04:16 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 16:04:16 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 16:04:16 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 16:04:16 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 16:04:16 DEBUG   opendrift.export.io_netcdf:216: Importing with Xarray from D:/backtrack/oceandrift_48h/likelihood/fwd1315feb.nc
# 16:04:16 INFO    opendrift:118: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object
# 16:04:16 INFO    opendrift.models.basemodel:4646: 	calculating for origin_marker 0...
# 16:04:16 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 16:04:16 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-13 03:12 to 2023-02-15 03:12 UTC (49 steps)'}>,
#  <Figure size 940.97x1100 with 2 Axes>)

# %%
lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
#       2 latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)
#
# NameError: name 'back' is not defined

# %%
fwd = xr.open_dataset(outfile)

# %%
xfwd = fwd.isel(trajectory=hits[0])

# %% [markdown]
# #### Start lon and lat of FWD 'hits'

# %%
lon = []       # lon for 'hits'
lat = []       # lat for 'hits'

for i in range(len(xfwd.trajectory)):
    lon.append(xfwd.isel(trajectory=i).lon.values[0])
    lat.append(xfwd.isel(trajectory=i).lat.values[0])

# %% [markdown]
# #### Start lon and lat of all FWD runs

# %%
lonall = []
latall = []

for i in range(len(fwd.trajectory)):
    lonall.append(fwd.isel(trajectory=i).lon.values[0])
    latall.append(fwd.isel(trajectory=i).lat.values[0])

# %%
# Set the desired grid size
grid_size_lon = 0.120  # Change this to your desired grid size
grid_size_lat = 0.100

# Calculate the number of grid cells in each dimension
lon_bins = np.arange(np.min(lonall), np.max(lonall) + grid_size_lon, grid_size_lon)
lat_bins = np.arange(np.min(latall), np.max(latall) + grid_size_lat, grid_size_lat)

# %%
def count_points_in_grid(lon, lat, lonbins, latbins):
    
    lobi = []
    labi = []
    for i in range(len(lonbins)-1):
        lobi.append((lonbins[i]+lonbins[i+1])/2)
    for i in range(len(latbins)-1):
        labi.append((latbins[i]+latbins[i+1])/2)
        
    # Count the number of points in each grid cell
    counts, xedges, yedges = np.histogram2d(lon, lat, bins=[lonbins, latbins])
    
    # Create a new DataArray with the counts and assign coordinates
    counts_dataarray = xr.DataArray(counts, coords=[('lon_bin', lobi), ('lat_bin', labi)])
    
    return counts_dataarray 

# Call the function to count points in grid cells
grid_counts = count_points_in_grid(lon, lat, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:02:22 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:02:22 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-13 03:12 to 2023-02-15 03:12 UTC (49 steps)'}>,
#  <Figure size 940.97x1100 with 2 Axes>)

# %%
# Call the function to count points in grid cells
grid_counts_all = count_points_in_grid(lonall, latall, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts_all, clabel='$N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:02:31 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:02:31 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-13 03:12 to 2023-02-15 03:12 UTC (49 steps)'}>,
#  <Figure size 940.97x1100 with 2 Axes>)

# %%
o_hit.plot(background=grid_counts/grid_counts_all, clabel='$n_j / N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:02:44 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:02:44 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-13 03:12 to 2023-02-15 03:12 UTC (49 steps)'}>,
#  <Figure size 940.97x1100 with 2 Axes>)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.pcolormesh(grid_counts_all)

# %%
lonback = []       # lon for bwd
latback = []       # lat for bwd

for i in range(len(back241.trajectory)):
    lonback.append(back241.isel(trajectory=i).lon.values[-1])
    latback.append(back241.isel(trajectory=i).lat.values[-1])

# %%
grid_counts_back = count_points_in_grid(lonback, latback, lon_bins, lat_bins)

# %%
o_back = opendrift.open(outfile_bwd)
# Out:
# 14:04:38 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 14:04:38 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 14:04:38 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 14:04:38 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 14:04:38 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 14:04:38 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 14:04:38 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 14:04:38 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/bwd1315feb241.nc
# 14:04:38 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 14:04:38 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 14:04:38 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_back.plot(background=grid_counts_back, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:04:41 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:04:41 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-15 03:12 to 2023-02-13 03:12 UTC (49 steps)'}>,
#  <Figure size 941.873x1100 with 2 Axes>)

# %%
fig = plt.figure(1, figsize=(12,10))
ax = fig.add_subplot(111, projection=ccrs.Mercator())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')

back241.traj.plot(linewidth=0.5,color='red')

# ax.plot(back192.isel(time=0).lon.values, back192.isel(time=0).lat.values, 'ro', markersize=0.5, transform=ccrs.Geodetic())
# for i in hits: 
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', markersize=0.5, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-02-13 03:12:08', '2023-02-15 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
o_hit.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 14:05:42 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:05:42 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-13 03:12 to 2023-02-15 03:12 UTC (49 steps)'}>,
#  <Figure size 940.97x1100 with 2 Axes>)

# %%
grid_counts.lon_bin
# Out:
# <xarray.DataArray 'lon_bin' (lon_bin: 14)>
# array([25.384314, 25.464314, 25.544314, 25.624314, 25.704314, 25.784314,
#        25.864314, 25.944314, 26.024314, 26.104314, 26.184314, 26.264314,
#        26.344314, 26.424314])
# Coordinates:
#   * lon_bin  (lon_bin) float64 25.38 25.46 25.54 25.62 ... 26.26 26.34 26.42
