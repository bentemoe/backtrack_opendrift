# %%
import os
os.path

from datetime import datetime, timedelta
import cmocean

import pyproj
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import trajan as ta
import pandas as pd

import opendrift
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.physics_methods import wind_drift_factor_from_trajectory, distance_between_trajectories, skillscore_liu_weissberg

import cartopy.crs as ccrs
from matplotlib.lines import Line2D

from scipy.spatial import ConvexHull, convex_hull_plot_2d

import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from matplotlib.lines import Line2D

# %%
d03 = xr.open_dataset('C:/Users/bente/Documents/BACKTRACK/backtracking/data/OO-2023.nc')       # all drifter data
d03 = d03.traj.gridtime('1H')
d03 = d03.isel(trajectory=0)             # drifter OO-2023-03

# %%
startlat = d03.lat.sel(time=slice(datetime(2023, 1, 30, 3, 12, 8), datetime(2023, 1, 30, 3, 12, 8))).values
startlon = d03.lon.sel(time=slice(datetime(2023, 1, 30, 3, 12, 8), datetime(2023, 1, 30, 3, 12, 8))).values

# %%
len(hits[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(hits[0])
#
# NameError: name 'hits' is not defined

# %%
reader_globcur = reader_netCDF_CF_generic.Reader("C:/Users/bente/Documents/THESIS/Globcurrent/*.nc")

# %%
duration = timedelta(hours=120)                # 5 days
start_time = datetime(2023,1,25,3,12,8)
end_time = start_time + duration

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/bwd2530jan500.nc"

# %%
orev = OceanDrift(loglevel=50)
orev.add_reader([reader_globcur])
orev.set_config('drift:advection_scheme', 'runge-kutta4')
orev.set_config('drift:horizontal_diffusivity', 20)
orev.seed_elements(lon=startlon, lat=startlat, radius=10000, radius_type='uniform', number=53, time=end_time)
orev.run(duration=duration, time_step=-900, time_step_output=3600, outfile=outfile_bwd)
# Out:
# 15:48:43 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.

# %%
back = xr.open_dataset(outfile_bwd)

# %%
diflon = np.max(back.isel(time=120).lon.values) - np.min(back.isel(time=120).lon.values)
diflat = np.max(back.isel(time=120).lat.values) - np.min(back.isel(time=120).lat.values)

# %%
diflat
# Out:
# 2.8790474

# %%
# Define domain of possible origin !!! WITH RANDOM UNIFORM SEEDING !!!
lons = np.zeros((120,120))
lats = np.zeros((120,120))
for j in range(120):
    lons[j] = np.random.uniform(np.min(back.isel(time=120).lon.values)-(0.5), np.max(back.isel(time=120).lon.values)+(0.5), 120) # Much coarser CCC
    lats[j] = np.random.uniform(np.min(back.isel(time=120).lat.values)-(0.5), np.max(back.isel(time=120).lat.values)+(0.5), 120)

# %%
np.min(back.lat.values)
# Out:
# -40.695507

# %%
np.max(back.lat.values)
# Out:
# -37.479378

# %%
# Set the desired grid size
grid_size_lon = 0.360  # Change this to your desired grid size
grid_size_lat = 0.300

# Calculate the number of grid cells in each dimension
lon_bins = np.arange(np.min(back.isel(time=120).lon.values)-(0.5), np.max(back.isel(time=120).lon.values)+(0.5), grid_size_lon)
lat_bins = np.arange(np.min(back.isel(time=120).lat.values)-(0.5), np.max(back.isel(time=120).lat.values)+(0.5), grid_size_lat)

# %%
binmesh = np.meshgrid(lon_bins, lat_bins)

# %%
lons = np.zeros((len(lon_bins)-1,(len(lat_bins)*20)-20))
lats = np.zeros((len(lon_bins)-1,(len(lat_bins)*20)-20))
for i in range(len(binmesh[0][0])-1):
    for j in range(len(binmesh[1])-1):
        lons[i][(j*20):((j+1)*20)] = np.random.uniform(binmesh[0][0][i], binmesh[0][0][i+1], 20) # Much coarser CCC
        lats[i][(j*20):((j+1)*20)] = np.random.uniform(binmesh[1][j][0], binmesh[1][j+1][0], 20)

# %% [markdown]
# # FWD

# %%
outfile = "D:/backtrack/oceandrift_48h/likelihood/fwd2530febdif2.nc"

# %%
ofwd = OceanDrift(loglevel=50)
ofwd.add_reader([reader_globcur])
ofwd.set_config('drift:advection_scheme', 'runge-kutta4')
ofwd.set_config('drift:horizontal_diffusivity', 20)
ofwd.seed_elements(lon=lons, lat=lats, radius=0, time=start_time)
ofwd.run(duration=duration, time_step=900, time_step_output=3600, outfile=outfile)

# %%
fwd = xr.open_dataset(outfile)

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)

#fwd.traj.plot(linewidth=0.1)

for i in range(len(fwd.trajectory)):
    ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

#back.traj.plot(linewidth=0.1,color='red')

#d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-30 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
ilat = d03.lat.sel(time=slice(datetime(2023, 1, 30, 3, 12, 8), datetime(2023, 1, 30, 3, 12, 8))).values
ilon = d03.lon.sel(time=slice(datetime(2023, 1, 30, 3, 12, 8), datetime(2023, 1, 30, 3, 12, 8))).values

# %%
## FORWARD ## 
lon0 = []
lat0 = []
lonend0 = []
latend0 = []
for j in range(len(fwd.trajectory)):
        ### calculating hits ###
        lon0.append(fwd.isel(trajectory=j).lon.values)
        lat0.append(fwd.isel(trajectory=j).lat.values)
        lonend0.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
        latend0.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
        
geod = pyproj.Geod(ellps='WGS84')
on = np.ones(len(lonend0))
dummy1, dummy2, dist2incident = geod.inv(lonend0, latend0, ilon*on, ilat*on)
hits = np.where(dist2incident<10000)

hit_start_lons0= []
hit_start_lats0= []
for m in range(len(hits)):
        hit_start_lons0.append(lon0[hits[0][m]][0])
        hit_start_lats0.append(lat0[hits[0][m]][0])

# %%
### PLOT ### 
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)

for i in range(len(fwd.trajectory)):
    fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
    
for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

# for i in range(len(fwd.trajectory)):
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-30 03:12:08')).traj.plot(color='black')  

custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='grey', lw=4),
                Line2D([0], [0], color='black', lw=4)]

ax.legend(custom_lines, ['Fwd - Elements hitting target','Backward traj.', 'Fwd - Elements NOT hitting target', 'Observed drifter trajectory'])

plt.gca().autoscale()
plt.title('Opendrift Leeway - 25-01-2023 03:12 to 27-01-2023 03:12 UTC (49 steps)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 7
#       4 ax.gridlines(draw_labels=True)
#       6 for i in range(len(fwd.trajectory)):
# ----> 7     fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
#       9 for i in hits:
#      10     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\trajan\plot\__init__.py:136, in Plot.__call__(self, *args, **kwargs)
#     135 def __call__(self, *args, **kwargs):
# --> 136     return self.lines(*args, **kwargs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\trajan\plot\__init__.py:197, in Plot.lines(self, *args, **kwargs)
#     195         paths = ax.plot(x, y, *args, **kwargs)
#     196     else:
# --> 197         paths = ax.plot(x, y, transform=self.gcrs, *args, **kwargs)
#     199 return paths
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\axes\_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\axes\_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\axes\_base.py:2343, in _AxesBase._update_line_limits(self, line)
#    2341 if self.transData.is_affine:
#    2342     line_trans_path = line._get_transformed_path()
# -> 2343     na_path, _ = line_trans_path.get_transformed_path_and_affine()
#    2344     data_path = trf_to_data.transform_path_affine(na_path)
#    2345 else:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\transforms.py:2781, in TransformedPath.get_transformed_path_and_affine(self)
#    2775 def get_transformed_path_and_affine(self):
#    2776     """
#    2777     Return a copy of the child path, with the non-affine part of
#    2778     the transform already applied, along with the affine part of
#    2779     the path necessary to complete the transformation.
#    2780     """
# -> 2781     self._revalidate()
#    2782     return self._transformed_path, self.get_affine()
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\transforms.py:2757, in TransformedPath._revalidate(self)
#    2751 def _revalidate(self):
#    2752     # only recompute if the invalidation includes the non_affine part of
#    2753     # the transform
#    2754     if (self._invalid & self.INVALID_NON_AFFINE == self.INVALID_NON_AFFINE
#    2755             or self._transformed_path is None):
#    2756         self._transformed_path = \
# -> 2757             self._transform.transform_path_non_affine(self._path)
#    2758         self._transformed_points = \
#    2759             Path._fast_from_codes_and_verts(
#    2760                 self._transform.transform_non_affine(self._path.vertices),
#    2761                 None, self._path)
#    2762     self._invalid = 0
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\transforms.py:2431, in CompositeGenericTransform.transform_path_non_affine(self, path)
#    2429     return path
#    2430 elif not self._a.is_affine and self._b.is_affine:
# -> 2431     return self._a.transform_path_non_affine(path)
#    2432 else:
#    2433     return self._b.transform_path_non_affine(
#    2434                             self._a.transform_path(path))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\mpl\geoaxes.py:190, in InterProjectionTransform.transform_path_non_affine(self, src_path)
#     186 geoms = cpatch.path_to_geos(src_path,
#     187                             getattr(self, 'force_path_ccw', False))
#     189 for geom in geoms:
# --> 190     proj_geom = self.target_projection.project_geometry(
#     191         geom, self.source_projection)
#     192     transformed_geoms.append(proj_geom)
#     194 if not transformed_geoms:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\crs.py:808, in Projection.project_geometry(self, geometry, src_crs)
#     806 if not method_name:
#     807     raise ValueError(f'Unsupported geometry type {geom_type!r}')
# --> 808 return getattr(self, method_name)(geometry, src_crs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\crs.py:913, in Projection._project_multiline(self, geometry, src_crs)
#     911 geoms = []
#     912 for geom in geometry.geoms:
# --> 913     r = self._project_line_string(geom, src_crs)
#     914     if r:
#     915         geoms.extend(r.geoms)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\crs.py:814, in Projection._project_line_string(self, geometry, src_crs)
#     813 def _project_line_string(self, geometry, src_crs):
# --> 814     return cartopy.trace.project_linear(geometry, src_crs, self)
#
# File lib/cartopy/trace.pyx:600, in cartopy.trace.project_linear()
#
# File lib/cartopy/trace.pyx:500, in cartopy.trace._project_segment()
#
# File lib/cartopy/trace.pyx:453, in cartopy.trace.bisect()
#
# File lib/cartopy/trace.pyx:218, in cartopy.trace.CartesianInterpolator.interpolate()
#
# File lib/cartopy/trace.pyx:184, in cartopy.trace.Interpolator.project()
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\pyproj\transformer.py:804, in Transformer.transform(self, xx, yy, zz, tt, radians, errcheck, direction, inplace)
#     802     intime = None
#     803 # call pj_transform.  inx,iny,inz buffers modified in place.
# --> 804 self._transformer._transform(
#     805     inx,
#     806     iny,
#     807     inz=inz,
#     808     intime=intime,
#     809     direction=direction,
#     810     radians=radians,
#     811     errcheck=errcheck,
#     812 )
#     813 # if inputs were lists, tuples or floats, convert back.
#     814 outx = _convertback(x_data_type, inx)
#
# File pyproj\_transformer.pyx:705, in pyproj._transformer._Transformer._transform()
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\pyproj\exceptions.py:19, in ProjError.clear()
#      16         ProjError.clear()
#      17     super().__init__(error_message)
# ---> 19 @staticmethod
#      20 def clear() -> None:
#      21     """
#      22     This will clear the internal PROJ error message.
#      23     """
#      24     ProjError.internal_proj_error = None
#
# KeyboardInterrupt:

# %%
len(fwd.trajectory)
# Out:
# 36480

# %%
len(hits[0])
# Out:
# 53

# %%
o_hit = opendrift.open(outfile, elements=hits[0])
# Out:
# 16:25:56 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 16:25:57 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 16:25:57 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 16:25:57 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 16:25:57 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 16:25:57 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 16:25:57 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/fwd2530febdif2.nc
# 16:25:59 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 20.0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 16:25:59 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 16:25:59 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_hit.plot()
# Out:
# 16:26:00 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=False, lscale=None
# 16:26:00 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (15.232513999938966, 20.75088920593262, -40.89652938842774, -37.36555557250976)..
# 16:26:05 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (15.232513999938966, 20.75088920593262, -40.89652938842774, -37.36555557250976)..
# 16:26:06 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (15.232513999938966, 20.75088920593262, -40.89652938842774, -37.36555557250976)..
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-30 03:12 UTC (121 steps)'}>,
#  <Figure size 1100x907.36 with 1 Axes>)

# %%
of = opendrift.open_xarray(outfile)
density_fwd = of.get_histogram(pixelsize_m=5000).isel(time=0).isel(origin_marker=0)
density_fwd = density_fwd.where(density_fwd>0)
density_fwd = density_fwd/density_fwd.sum()*100
vmax = density_fwd.max()
o_hit.plot(background=density_fwd, clabel='Probability of origin [%]', fast=True, markersize=.5, lalpha=.02, vmin=0)
# Out:
# 15:36:49 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 15:36:49 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 15:36:49 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 15:36:49 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 15:36:49 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 15:36:50 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 15:36:50 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 15:36:50 DEBUG   opendrift.export.io_netcdf:216: Importing with Xarray from D:/backtrack/oceandrift_48h/likelihood/fwd2530febdif2.nc
# 15:36:50 INFO    opendrift:118: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object
# 15:36:50 INFO    opendrift.models.basemodel:4646: 	calculating for origin_marker 0...
# 15:36:51 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 15:36:51 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 6
#       4 density_fwd = density_fwd/density_fwd.sum()*100
#       5 vmax = density_fwd.max()
# ----> 6 o_hit.plot(background=density_fwd, clabel='Probability of origin [%]', fast=True, markersize=.5, lalpha=.02, vmin=0)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\opendrift\models\basemodel.py:4516, in OpenDriftSimulation.plot(self, background, buffer, corners, linecolor, filename, show, vmin, vmax, compare, cmap, lvmin, lvmax, skip, scale, show_scalar, contourlines, drifter, colorbar, linewidth, lcs, show_elements, show_trajectories, show_initial, density_pixelsize_m, bgalpha, clabel, surface_color, submerged_color, markersize, title, legend, legend_loc, lscale, fast, hide_landmask, **kwargs)
#    4514 else:
#    4515     if show is True:
# -> 4516         plt.show()
#    4518 return ax, fig
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\IPython\core\formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\figure.py:3134, in Figure.draw(self, renderer)
#    3132 if self.axes and self.get_layout_engine() is not None:
#    3133     try:
# -> 3134         self.get_layout_engine().execute(self)
#    3135     except ValueError:
#    3136         pass
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\layout_engine.py:178, in TightLayoutEngine.execute(self, fig)
#     176 renderer = fig._get_renderer()
#     177 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 178     kwargs = get_tight_layout_figure(
#     179         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     180         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     181         rect=info['rect'])
#     182 if kwargs:
#     183     fig.subplots_adjust(**kwargs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)
#     280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\mpl\geoaxes.py:511, in GeoAxes.get_tightbbox(self, renderer, *args, **kwargs)
#     508 # Shared processing steps
#     509 self._draw_preprocess(renderer)
# --> 511 return super().get_tightbbox(renderer, *args, **kwargs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\axes\_base.py:4408, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4405     bbox_artists = self.get_default_bbox_extra_artists()
#    4407 for a in bbox_artists:
# -> 4408     bbox = a.get_tightbbox(renderer)
#    4409     if (bbox is not None
#    4410             and 0 < bbox.width < np.inf
#    4411             and 0 < bbox.height < np.inf):
#    4412         bb.append(bbox)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\legend.py:1026, in Legend.get_tightbbox(self, renderer)
#    1024 def get_tightbbox(self, renderer=None):
#    1025     # docstring inherited
# -> 1026     return self._legend_box.get_window_extent(renderer)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\offsetbox.py:402, in OffsetBox.get_window_extent(self, renderer)
#     400 bbox = self.get_bbox(renderer)
#     401 try:  # Some subclasses redefine get_offset to take no args.
# --> 402     px, py = self.get_offset(bbox, renderer)
#     403 except TypeError:
#     404     px, py = self.get_offset()
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\offsetbox.py:60, in _compat_get_offset.<locals>.get_offset(self, *args, **kwargs)
#      56 params = _api.select_matching_signature(sigs, self, *args, **kwargs)
#      57 bbox = (params["bbox"] if "bbox" in params else
#      58         Bbox.from_bounds(-params["xdescent"], -params["ydescent"],
#      59                          params["width"], params["height"]))
# ---> 60 return meth(params["self"], bbox, params["renderer"])
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\offsetbox.py:313, in OffsetBox.get_offset(self, bbox, renderer)
#     298 @_compat_get_offset
#     299 def get_offset(self, bbox, renderer):
#     300     """
#     301     Return the offset as a tuple (x, y).
#     302
#    (...)
#     310     renderer : `.RendererBase` subclass
#     311     """
#     312     return (
# --> 313         self._offset(bbox.width, bbox.height, -bbox.x0, -bbox.y0, renderer)
#     314         if callable(self._offset)
#     315         else self._offset)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\legend.py:695, in Legend._findoffset(self, width, height, xdescent, ydescent, renderer)
#     692 """Helper function to locate the legend."""
#     694 if self._loc == 0:  # "best".
# --> 695     x, y = self._find_best_position(width, height, renderer)
#     696 elif self._loc in Legend.codes.values():  # Fixed location.
#     697     bbox = Bbox.from_bounds(0, 0, width, height)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\legend.py:1125, in Legend._find_best_position(self, width, height, renderer, consider)
#    1121 assert self.isaxes  # always holds, as this is only called internally
#    1123 start_time = time.perf_counter()
# -> 1125 bboxes, lines, offsets = self._auto_legend_data()
#    1127 bbox = Bbox.from_bounds(0, 0, width, height)
#    1128 if consider is None:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\legend.py:936, in Legend._auto_legend_data(self)
#     933     lines.append(
#     934         artist.get_transform().transform_path(artist.get_path()))
#     935 elif isinstance(artist, Collection):
# --> 936     transform, transOffset, hoffsets, _ = artist._prepare_points()
#     937     if len(hoffsets):
#     938         for offset in transOffset.transform(hoffsets):
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\collections.py:328, in Collection._prepare_points(self)
#     325     offsets = np.ma.column_stack([xs, ys])
#     327 if not transform.is_affine:
# --> 328     paths = [transform.transform_path_non_affine(path)
#     329              for path in paths]
#     330     transform = transform.get_affine()
#     331 if not offset_trf.is_affine:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\collections.py:328, in <listcomp>(.0)
#     325     offsets = np.ma.column_stack([xs, ys])
#     327 if not transform.is_affine:
# --> 328     paths = [transform.transform_path_non_affine(path)
#     329              for path in paths]
#     330     transform = transform.get_affine()
#     331 if not offset_trf.is_affine:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\transforms.py:2431, in CompositeGenericTransform.transform_path_non_affine(self, path)
#    2429     return path
#    2430 elif not self._a.is_affine and self._b.is_affine:
# -> 2431     return self._a.transform_path_non_affine(path)
#    2432 else:
#    2433     return self._b.transform_path_non_affine(
#    2434                             self._a.transform_path(path))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\mpl\geoaxes.py:190, in InterProjectionTransform.transform_path_non_affine(self, src_path)
#     186 geoms = cpatch.path_to_geos(src_path,
#     187                             getattr(self, 'force_path_ccw', False))
#     189 for geom in geoms:
# --> 190     proj_geom = self.target_projection.project_geometry(
#     191         geom, self.source_projection)
#     192     transformed_geoms.append(proj_geom)
#     194 if not transformed_geoms:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\crs.py:808, in Projection.project_geometry(self, geometry, src_crs)
#     806 if not method_name:
#     807     raise ValueError(f'Unsupported geometry type {geom_type!r}')
# --> 808 return getattr(self, method_name)(geometry, src_crs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\crs.py:915, in Projection._project_multiline(self, geometry, src_crs)
#     913     r = self._project_line_string(geom, src_crs)
#     914     if r:
# --> 915         geoms.extend(r.geoms)
#     916 if geoms:
#     917     return sgeom.MultiLineString(geoms)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\shapely\geometry\base.py:959, in GeometrySequence.__iter__(self)
#     957 def __iter__(self):
#     958     for i in range(self.__len__()):
# --> 959         yield self._get_geom_item(i)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\shapely\geometry\base.py:955, in GeometrySequence._get_geom_item(self, i)
#     954 def _get_geom_item(self, i):
# --> 955     return shapely.get_geometry(self._parent, i)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\shapely\_geometry.py:557, in get_geometry(geometry, index, **kwargs)
#     520 @multithreading_enabled
#     521 def get_geometry(geometry, index, **kwargs):
#     522     """Returns the nth geometry from a collection of geometries.
#     523
#     524     Parameters
#    (...)
#     555     True
#     556     """
# --> 557     return lib.get_geometry(geometry, np.intc(index), **kwargs)
#
# KeyboardInterrupt:

# %%
density_forwards.isel(lon_bin=40).isel(lat_bin=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 density_forwards.isel(lon_bin=40).isel(lat_bin=40)
#
# NameError: name 'density_forwards' is not defined

# %%
# lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
# latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)

# %%
fwd = xr.open_dataset(outfile)

# %%
xfwd = fwd.isel(trajectory=hits[0])

# %% [markdown]
# #### Start lon and lat of FWD 'hits'

# %%
lon = []       # lon for 'hits'
lat = []       # lat for 'hits'

for i in range(len(xfwd.trajectory)):
    lon.append(xfwd.isel(trajectory=i).lon.values[0])
    lat.append(xfwd.isel(trajectory=i).lat.values[0])

# %% [markdown]
# #### Start lon and lat of all FWD runs

# %%
lonall = []
latall = []

for i in range(len(fwd.trajectory)):
    lonall.append(fwd.isel(trajectory=i).lon.values[0])
    latall.append(fwd.isel(trajectory=i).lat.values[0])

# %%
# # Set the desired grid size
# grid_size_lon = 0.080  # Change this to your desired grid size
# grid_size_lat = 0.070

# # Calculate the number of grid cells in each dimension
# lon_bins = np.arange(np.min(lonall), np.max(lonall) + grid_size_lon, grid_size_lon)
# lat_bins = np.arange(np.min(latall), np.max(latall) + grid_size_lat, grid_size_lat)

# %%
def count_points_in_grid(lon, lat, lonbins, latbins):
    
    lobi = []
    labi = []
    for i in range(len(lonbins)-1):
        lobi.append((lonbins[i]+lonbins[i+1])/2)
    for i in range(len(latbins)-1):
        labi.append((latbins[i]+latbins[i+1])/2)
        
    # Count the number of points in each grid cell
    counts, xedges, yedges = np.histogram2d(lon, lat, bins=[lonbins, latbins])
    
    # Create a new DataArray with the counts and assign coordinates
    counts_dataarray = xr.DataArray(counts, coords=[('lon_bin', lobi), ('lat_bin', labi)])
    
    return counts_dataarray 

# Call the function to count points in grid cells
grid_counts = count_points_in_grid(lon, lat, lon_bins, lat_bins)

# %%
len(lon_bins)
# Out:
# 17

# %%
o_hit.plot(background=grid_counts, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 16:36:19 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 16:36:19 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-30 03:12 UTC (121 steps)'}>,
#  <Figure size 1100x907.36 with 2 Axes>)

# %%
# Call the function to count points in grid cells
grid_counts_all = count_points_in_grid(lonall, latall, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts_all, clabel='$N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 16:36:20 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 16:36:20 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-30 03:12 UTC (121 steps)'}>,
#  <Figure size 1100x907.36 with 2 Axes>)

# %%
o_hit.plot(background=grid_counts/grid_counts_all, clabel='$n_j / N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 16:36:33 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 16:36:33 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-30 03:12 UTC (121 steps)'}>,
#  <Figure size 1100x907.36 with 2 Axes>)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.pcolormesh(grid_counts_all)

# %%
likelihood = grid_counts/grid_counts_all

# %%
likelihood.plot(x=grid_counts.dims[0], y=grid_counts.dims[1], cmap='YlOrRd')
plt.title('likelihood: nj/Nj')
plt.grid()

# %% [markdown]
# ### Equal Prior Probability

# %%
prior = grid_counts_all/len(fwd.trajectory)

# %% [markdown]
# ### Variable Prior Probability

# %% [markdown]
# Variable prior by LATITUDE:

# %%
varprior1 = (grid_counts_all[:,0:3]-4)
varprior2 = (grid_counts_all[:,3:7]+7)
varprior3 = (grid_counts_all[:,7:11]-4)

# %%
varprior = xr.concat([varprior1, varprior2,varprior3], dim='lat_bin')/len(fwd.trajectory)

# %% [markdown]
# Variable prior by LONGITUDE:

# %%
varprior1 = (grid_counts_all[0:7]+10) 
varprior2 = (grid_counts_all[7:14]-10)

# %%
varprior = xr.concat([varprior1, varprior2], dim='lon_bin')/len(fwd.trajectory)

# %% [markdown]
# Check if sum of all prior probabilities is 1!!!

# %%
np.sum(prior)
# Out:
# <xarray.DataArray ()>
# array(0.94736842)

# %%
np.sum(varprior)
# Out:
# <xarray.DataArray ()>
# array(0.82894737)

# %% [markdown]
# ### Posterior (and norm. const.)

# %%
norm_const = len(hits)/len(fwd.trajectory)
posterior = (likelihood*prior)/norm_const

# %%
norm_const = len(hits)/len(fwd.trajectory)
varposterior = (likelihood*varprior)/norm_const

# %% [markdown]
# For equal prior:

# %%
posterior.plot(x=posterior.dims[0], y=posterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %% [markdown]
# For variable prior:

# %%
varprior.plot(x=varprior.dims[0], y=varprior.dims[1], cmap='YlOrRd')
plt.title('P(Aj): Prior probability')
plt.grid()

# %%
varposterior.plot(x=varposterior.dims[0], y=varposterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %%
o_hit.plot(posterior, clabel='Posterior Probability', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 16:37:10 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 16:37:10 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-30 03:12 UTC (121 steps)'}>,
#  <Figure size 1100x907.36 with 2 Axes>)

# %%
fig = plt.figure(1, figsize=(18,7))
ax = fig.add_subplot(111, projection=ccrs.PlateCarree())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

#posterior.plot.pcolormesh(x="lon_bin", y="lat_bin", ax=ax, cmap='YlOrRd', infer_intervals=True)

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.1, color='grey')
    ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=0.6, transform=ccrs.PlateCarree(), label='startloc. fwd OD simulations')

ax.plot(d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-25 03:12:08')).lon.values, d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-25 03:12:08')).lat.values, 'X', color='red', mec='black', markersize=14, transform=ccrs.PlateCarree(), label='startloc. observed drifter')  

post = posterior.plot.pcolormesh(x="lon_bin", y="lat_bin", ax=ax, cmap='YlOrRd', label='Posterior probability')
#fig.colorbar(post, ax=ax, location='right', label='Posterior')

plt.legend(fontsize=13)
plt.gca().autoscale()
plt.title('Posterior Probability - Opendrift OceanDrift - 25-01-2023 03:12 to 30-01-2023 03:12 UTC', fontsize=12)
plt.show()

# %% [markdown]
# # BWD

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/bwd2530jan53.nc"
back53 = xr.open_dataset(outfile_bwd)

# %%
lonback = []       # lon for bwd
latback = []       # lat for bwd

for i in range(len(back53.trajectory)):
    lonback.append(back53.isel(trajectory=i).lon.values[-1])
    latback.append(back53.isel(trajectory=i).lat.values[-1])

# %%
grid_counts_back = count_points_in_grid(lonback, latback, lon_bins, lat_bins)

# %%
o_back = opendrift.open(outfile_bwd)
# Out:
# 16:41:09 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 16:41:09 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 16:41:09 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 16:41:09 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 16:41:09 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 16:41:09 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 16:41:09 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 16:41:09 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/bwd2530jan53.nc
# 16:41:09 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 20.0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 16:41:09 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 16:41:09 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_back.plot(background=grid_counts_back, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 16:41:09 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 16:41:09 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-30 03:12 to 2023-01-25 03:12 UTC (121 steps)'}>,
#  <Figure size 1100x919.225 with 2 Axes>)

# %%
grid_counts_back.plot(x=grid_counts_back.dims[0], y=grid_counts_back.dims[1], cmap='YlOrRd')
plt.title('Backwards nj')
plt.grid()

# %%
fig = plt.figure(1, figsize=(12,10))
ax = fig.add_subplot(111, projection=ccrs.Mercator())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')

back53.traj.plot(linewidth=0.5,color='red')

# ax.plot(back192.isel(time=0).lon.values, back192.isel(time=0).lat.values, 'ro', markersize=0.5, transform=ccrs.Geodetic())
# for i in hits: 
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', markersize=0.5, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-30 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
o_hit.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 16:41:12 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 16:41:12 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-01-25 03:12 to 2023-01-30 03:12 UTC (121 steps)'}>,
#  <Figure size 1100x907.36 with 2 Axes>)

# %%
grid_counts.lon_bin
# Out:
# <xarray.DataArray 'lon_bin' (lon_bin: 16)>
# array([15.333595, 15.693595, 16.053595, 16.413595, 16.773595, 17.133595,
#        17.493595, 17.853595, 18.213595, 18.573595, 18.933595, 19.293595,
#        19.653595, 20.013595, 20.373595, 20.733595])
# Coordinates:
#   * lon_bin  (lon_bin) float64 15.33 15.69 16.05 16.41 ... 20.01 20.37 20.73
