# %%
import os
os.path

from datetime import datetime, timedelta
import cmocean

import pyproj
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import trajan as ta
import pandas as pd

import opendrift
from opendrift.models.oceandrift import OceanDrift
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.physics_methods import wind_drift_factor_from_trajectory, distance_between_trajectories, skillscore_liu_weissberg

import cartopy.crs as ccrs
from matplotlib.lines import Line2D

from scipy.spatial import ConvexHull, convex_hull_plot_2d

import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from matplotlib.lines import Line2D

# %%
d03 = xr.open_dataset('C:/Users/bente/Documents/BACKTRACK/backtracking/data/OO-2023.nc')       # all drifter data
d03 = d03.traj.gridtime('1H')
d03 = d03.isel(trajectory=0)             # drifter OO-2023-03

# %%
startlat = d03.lat.sel(time=slice(datetime(2023, 2, 14, 3, 12, 8), datetime(2023, 2, 14, 3, 12, 8))).values
startlon = d03.lon.sel(time=slice(datetime(2023, 2, 14, 3, 12, 8), datetime(2023, 2, 14, 3, 12, 8))).values

# %%
len(hits[0])
# Out:
# 59

# %%
reader_globcur = reader_netCDF_CF_generic.Reader("C:/Users/bente/Documents/THESIS/Globcurrent/*.nc")
# Out:
# 14:20:06 INFO    opendrift.readers.reader_netCDF_CF_generic:129: Opening dataset: C:/Users/bente/Documents/THESIS/Globcurrent/*.nc
# 14:20:06 INFO    opendrift.readers.reader_netCDF_CF_generic:131: Opening files with MFDataset
# 14:20:07 DEBUG   opendrift.readers.reader_netCDF_CF_generic:146: Finding coordinate variables.
# 14:20:07 DEBUG   opendrift.readers.reader_netCDF_CF_generic:163: Parsing CF grid mapping dictionary: {'grid_mapping_name': 'latitude_longitude', 'semi_major_axis': 6378137, 'inverse_flattening': 298.257223563}
# 14:20:07 INFO    opendrift.readers.reader_netCDF_CF_generic:170: Could not parse CF grid_mapping
# 14:20:07 INFO    opendrift.readers.reader_netCDF_CF_generic:285: Grid coordinates are detected, but proj4 string not given: assuming latlong
# 14:20:07 DEBUG   opendrift.readers.basereader.variables:546: Setting buffer size 6 for reader C:/Users/bente/Documents/THESIS/Globcurrent/*.nc, assuming a maximum average speed of 5 m/s and time span of 6:00:00
# 14:20:07 INFO    opendrift.readers.basereader:158: Variable x_sea_water_velocity will be rotated from eastward_sea_water_velocity
# 14:20:07 INFO    opendrift.readers.basereader:158: Variable y_sea_water_velocity will be rotated from northward_sea_water_velocity
# 14:20:07 DEBUG   opendrift.readers.basereader:168: Variable mapping: ['sea_floor_depth_below_sea_level'] -> ['land_binary_mask'] is not activated

# %%
duration = timedelta(hours=288)                # 5 days
start_time = datetime(2023,2,2,3,12,8)
end_time = start_time + duration

# %%
outfile_bwd = "D:/backtrack/oceandrift_48h/likelihood/bwd0214feb59.nc"

# %%
orev = OceanDrift(loglevel=50)
orev.add_reader([reader_globcur])
orev.set_config('drift:advection_scheme', 'runge-kutta4')
orev.set_config('drift:horizontal_diffusivity', 20)
orev.seed_elements(lon=startlon, lat=startlat, radius=10000, radius_type='uniform', number=100, time=end_time)
orev.run(duration=duration, time_step=-900, time_step_output=3600, outfile=outfile_bwd)
# Out:
# 14:20:17 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.

# %%
back59 = xr.open_dataset(outfile_bwd)

# %%
# diflon = np.max(back.isel(time=120).lon.values) - np.min(back.isel(time=120).lon.values)
# diflat = np.max(back.isel(time=120).lat.values) - np.min(back.isel(time=120).lat.values)

# %%
end_time
# Out:
# datetime.datetime(2023, 2, 14, 3, 12, 8)

# %%
# # Define domain of possible origin !!! WITH RANDOM UNIFORM SEEDING !!!
# lons = np.zeros((120,120))
# lats = np.zeros((120,120))
# for j in range(120):
#     lons[j] = np.random.uniform(np.min(back.isel(time=120).lon.values)-(0.5), np.max(back.isel(time=120).lon.values)+(0.5), 120) # Much coarser CCC
#     lats[j] = np.random.uniform(np.min(back.isel(time=120).lat.values)-(0.5), np.max(back.isel(time=120).lat.values)+(0.5), 120)

# %%
# np.min(back.lat.values)

# %%
# np.max(back.lat.values)

# %%
# Set the desired grid size
grid_size_lon = 0.120  # Change this to your desired grid size
grid_size_lat = 0.100

# Calculate the number of grid cells in each dimension
lon_bins = np.arange(np.min(back.isel(time=288).lon.values)-(0.5), np.max(back.isel(time=288).lon.values)+(0.5), grid_size_lon)
lat_bins = np.arange(np.min(back.isel(time=288).lat.values)-(0.5), np.max(back.isel(time=288).lat.values)+(0.5), grid_size_lat)

# %%
binmesh = np.meshgrid(lon_bins, lat_bins)

# %%
lons = np.zeros((len(lon_bins)-1,(len(lat_bins)*20)-20))
lats = np.zeros((len(lon_bins)-1,(len(lat_bins)*20)-20))
for i in range(len(binmesh[0][0])-1):
    for j in range(len(binmesh[1])-1):
        lons[i][(j*20):((j+1)*20)] = np.random.uniform(binmesh[0][0][i], binmesh[0][0][i+1], 20) # Much coarser CCC
        lats[i][(j*20):((j+1)*20)] = np.random.uniform(binmesh[1][j][0], binmesh[1][j+1][0], 20)

# %% [markdown]
# # FWD

# %%
outfile = "D:/backtrack/oceandrift_48h/likelihood/fwd0214febdif2.nc"

# %%
ofwd = OceanDrift(loglevel=50)
ofwd.add_reader([reader_globcur])
ofwd.set_config('drift:advection_scheme', 'runge-kutta4')
ofwd.set_config('drift:horizontal_diffusivity', 20)
ofwd.seed_elements(lon=lons, lat=lats, radius=0, time=start_time)
ofwd.run(duration=duration, time_step=900, time_step_output=3600, outfile=outfile)

# %%
fwd = xr.open_dataset(outfile)

# %%
len(fwd.trajectory)
# Out:
# 36480

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)

#fwd.traj.plot(linewidth=0.1)

for i in range(len(fwd.trajectory)):
    ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

#back.traj.plot(linewidth=0.1,color='red')

#d03.sel(time=slice('2023-01-25 03:12:08', '2023-01-30 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
ilat = d03.lat.sel(time=slice(datetime(2023, 2, 14, 3, 12, 8), datetime(2023, 2, 14, 3, 12, 8))).values
ilon = d03.lon.sel(time=slice(datetime(2023, 2, 14, 3, 12, 8), datetime(2023, 2, 14, 3, 12, 8))).values

# %%
## FORWARD ## 
lon0 = []
lat0 = []
lonend0 = []
latend0 = []
for j in range(len(fwd.trajectory)):
        ### calculating hits ###
        lon0.append(fwd.isel(trajectory=j).lon.values)
        lat0.append(fwd.isel(trajectory=j).lat.values)
        lonend0.append(fwd.isel(trajectory=j).lon.values[-1])   # lon at end of trajectory
        latend0.append(fwd.isel(trajectory=j).lat.values[-1])   # lat at end of trajectory
        
geod = pyproj.Geod(ellps='WGS84')
on = np.ones(len(lonend0))
dummy1, dummy2, dist2incident = geod.inv(lonend0, latend0, ilon*on, ilat*on)
hits = np.where(dist2incident<10000)

hit_start_lons0= []
hit_start_lats0= []
for m in range(len(hits)):
        hit_start_lons0.append(lon0[hits[0][m]][0])
        hit_start_lats0.append(lat0[hits[0][m]][0])

# %%
### PLOT ### 
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)

for i in range(len(fwd.trajectory)):
    fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
    
for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

# for i in range(len(fwd.trajectory)):
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-02-02 03:12:08', '2023-02-14 03:12:08')).traj.plot(color='black')  

custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='grey', lw=4),
                Line2D([0], [0], color='black', lw=4)]

ax.legend(custom_lines, ['Fwd - Elements hitting target','Backward traj.', 'Fwd - Elements NOT hitting target', 'Observed drifter trajectory'])

plt.gca().autoscale()
plt.title('Opendrift Leeway - 25-01-2023 03:12 to 27-01-2023 03:12 UTC (49 steps)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[121], line 7
#       4 ax.gridlines(draw_labels=True)
#       6 for i in range(len(fwd.trajectory)):
# ----> 7     fwd.isel(trajectory=i).traj.plot(linewidth=0.1)
#       9 for i in hits:
#      10     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\trajan\plot\__init__.py:136, in Plot.__call__(self, *args, **kwargs)
#     135 def __call__(self, *args, **kwargs):
# --> 136     return self.lines(*args, **kwargs)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\trajan\plot\__init__.py:197, in Plot.lines(self, *args, **kwargs)
#     195         paths = ax.plot(x, y, *args, **kwargs)
#     196     else:
# --> 197         paths = ax.plot(x, y, transform=self.gcrs, *args, **kwargs)
#     199 return paths
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\axes\_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\axes\_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\axes\_base.py:2343, in _AxesBase._update_line_limits(self, line)
#    2341 if self.transData.is_affine:
#    2342     line_trans_path = line._get_transformed_path()
# -> 2343     na_path, _ = line_trans_path.get_transformed_path_and_affine()
#    2344     data_path = trf_to_data.transform_path_affine(na_path)
#    2345 else:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\transforms.py:2781, in TransformedPath.get_transformed_path_and_affine(self)
#    2775 def get_transformed_path_and_affine(self):
#    2776     """
#    2777     Return a copy of the child path, with the non-affine part of
#    2778     the transform already applied, along with the affine part of
#    2779     the path necessary to complete the transformation.
#    2780     """
# -> 2781     self._revalidate()
#    2782     return self._transformed_path, self.get_affine()
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\transforms.py:2757, in TransformedPath._revalidate(self)
#    2751 def _revalidate(self):
#    2752     # only recompute if the invalidation includes the non_affine part of
#    2753     # the transform
#    2754     if (self._invalid & self.INVALID_NON_AFFINE == self.INVALID_NON_AFFINE
#    2755             or self._transformed_path is None):
#    2756         self._transformed_path = \
# -> 2757             self._transform.transform_path_non_affine(self._path)
#    2758         self._transformed_points = \
#    2759             Path._fast_from_codes_and_verts(
#    2760                 self._transform.transform_non_affine(self._path.vertices),
#    2761                 None, self._path)
#    2762     self._invalid = 0
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\matplotlib\transforms.py:2431, in CompositeGenericTransform.transform_path_non_affine(self, path)
#    2429     return path
#    2430 elif not self._a.is_affine and self._b.is_affine:
# -> 2431     return self._a.transform_path_non_affine(path)
#    2432 else:
#    2433     return self._b.transform_path_non_affine(
#    2434                             self._a.transform_path(path))
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\mpl\geoaxes.py:186, in InterProjectionTransform.transform_path_non_affine(self, src_path)
#     181 transformed_geoms = []
#     182 # Check whether this transform has the "force_path_ccw" attribute set.
#     183 # This is a cartopy extension to the Transform API to allow finer
#     184 # control of Path orientation handling (Path ordering is not important
#     185 # in matplotlib, but is in Cartopy).
# --> 186 geoms = cpatch.path_to_geos(src_path,
#     187                             getattr(self, 'force_path_ccw', False))
#     189 for geom in geoms:
#     190     proj_geom = self.target_projection.project_geometry(
#     191         geom, self.source_projection)
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\cartopy\mpl\patch.py:168, in path_to_geos(path, force_ccw)
#     166     geom = sgeom.Polygon(path_verts[:-1, :])
#     167 else:
# --> 168     geom = sgeom.LineString(path_verts)
#     170 # If geom is a Polygon and is contained within the last geom in
#     171 # collection, add it to its list of internal polygons, otherwise
#     172 # simply append it as a new external geom.
#     173 if geom.is_empty:
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\shapely\geometry\linestring.py:73, in LineString.__new__(self, coordinates)
#      68 if len(coordinates) == 0:
#      69     # empty geometry
#      70     # TODO better constructor + should shapely.linestrings handle this?
#      71     return shapely.from_wkt("LINESTRING EMPTY")
# ---> 73 geom = shapely.linestrings(coordinates)
#      74 if not isinstance(geom, LineString):
#      75     raise ValueError("Invalid values passed to LineString constructor")
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~\miniconda3\envs\opendrift\Lib\site-packages\shapely\creation.py:120, in linestrings(coords, y, z, indices, out, **kwargs)
#     118 coords = _xyz_to_coords(coords, y, z)
#     119 if indices is None:
# --> 120     return lib.linestrings(coords, out=out, **kwargs)
#     121 else:
#     122     return simple_geometries_1d(coords, indices, GeometryType.LINESTRING, out=out)
#
# KeyboardInterrupt:

# %%
### PLOT ### 
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)

for i in range(len(back.trajectory)):
    back.isel(trajectory=i).traj.plot(linewidth=0.1)
    
# for i in hits: 
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())
#     ax.plot(fwd.isel(trajectory=i).isel(time=0).lon.values, fwd.isel(trajectory=i).isel(time=0).lat.values, 'bo', mec='black', markersize=7, transform=ccrs.Geodetic())

# for i in range(len(fwd.trajectory)):
#     fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='red')
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'ro', mec='black', markersize=7, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-02-02 03:12:08', '2023-02-14 03:12:08')).traj.plot(color='black')  

custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='grey', lw=4),
                Line2D([0], [0], color='black', lw=4)]

ax.legend(custom_lines, ['Fwd - Elements hitting target','Backward traj.', 'Fwd - Elements NOT hitting target', 'Observed drifter trajectory'])

plt.gca().autoscale()
plt.title('Opendrift Leeway - 25-01-2023 03:12 to 27-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
len(hits[0])
# Out:
# 59

# %%
o_hit = opendrift.open(outfile, elements=hits[0])
# Out:
# 14:09:07 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 14:09:07 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 14:09:07 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 14:09:07 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 14:09:07 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 14:09:07 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 14:09:07 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/fwd0214febdif2.nc
# 14:09:13 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 20.0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 14:09:13 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 14:09:13 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_hit.plot()
# Out:
# 14:09:13 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=False, lscale=None
# 14:09:13 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (20.094058609008787, 26.5280403137207, -39.627299499511714, -35.64188079833984)..
# 14:09:31 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (20.094058609008787, 26.5280403137207, -39.627299499511714, -35.64188079833984)..
# 14:09:31 DEBUG   opendrift.readers.reader_global_landmask:83: Adding GSHHG shapes from cartopy, scale: i, extent: (20.094058609008787, 26.5280403137207, -39.627299499511714, -35.64188079833984)..
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-02 03:12 to 2023-02-14 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x860.409 with 1 Axes>)

# %%
of = opendrift.open_xarray(outfile)
density_fwd = of.get_histogram(pixelsize_m=5000).isel(time=0).isel(origin_marker=0)
density_fwd = density_fwd.where(density_fwd>0)
density_fwd = density_fwd/density_fwd.sum()*100
vmax = density_fwd.max()
o_hit.plot(background=density_fwd, clabel='Probability of origin [%]', fast=True, markersize=.5, lalpha=.02, vmin=0)
# Out:
# 14:09:32 DEBUG   opendrift.models.oceandrift:112: No machine learning correction available.
# 14:09:33 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 14:09:33 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 14:09:33 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 14:09:33 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 14:09:33 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 14:09:33 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 14:09:33 DEBUG   opendrift.export.io_netcdf:216: Importing with Xarray from D:/backtrack/oceandrift_48h/likelihood/fwd0214febdif2.nc
# 14:09:33 INFO    opendrift:118: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object
# 14:09:33 INFO    opendrift.models.basemodel:4646: 	calculating for origin_marker 0...
# 14:09:37 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:09:37 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-02 03:12 to 2023-02-14 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x860.409 with 2 Axes>)

# %%
# lonbin = np.arange(np.min(back.isel(time=48).lon.values)-(0.5), np.max(back.isel(time=48).lon.values)+(0.5), 0.025)
# latbin = np.arange(np.min(back.isel(time=48).lat.values)-(0.5), np.max(back.isel(time=48).lat.values)+(0.5), 0.025)

# %%
fwd = xr.open_dataset(outfile)

# %%
xfwd = fwd.isel(trajectory=hits[0])

# %% [markdown]
# #### Start lon and lat of FWD 'hits'

# %%
lon = []       # lon for 'hits'
lat = []       # lat for 'hits'

for i in range(len(xfwd.trajectory)):
    lon.append(xfwd.isel(trajectory=i).lon.values[0])
    lat.append(xfwd.isel(trajectory=i).lat.values[0])

# %% [markdown]
# #### Start lon and lat of all FWD runs

# %%
lonall = []
latall = []

for i in range(len(fwd.trajectory)):
    lonall.append(fwd.isel(trajectory=i).lon.values[0])
    latall.append(fwd.isel(trajectory=i).lat.values[0])

# %%
# # Set the desired grid size
# grid_size_lon = 0.080  # Change this to your desired grid size
# grid_size_lat = 0.070

# # Calculate the number of grid cells in each dimension
# lon_bins = np.arange(np.min(lonall), np.max(lonall) + grid_size_lon, grid_size_lon)
# lat_bins = np.arange(np.min(latall), np.max(latall) + grid_size_lat, grid_size_lat)

# %%
def count_points_in_grid(lon, lat, lonbins, latbins):
    
    lobi = []
    labi = []
    for i in range(len(lonbins)-1):
        lobi.append((lonbins[i]+lonbins[i+1])/2)
    for i in range(len(latbins)-1):
        labi.append((latbins[i]+latbins[i+1])/2)
        
    # Count the number of points in each grid cell
    counts, xedges, yedges = np.histogram2d(lon, lat, bins=[lonbins, latbins])
    
    # Create a new DataArray with the counts and assign coordinates
    counts_dataarray = xr.DataArray(counts, coords=[('lon_bin', lobi), ('lat_bin', labi)])
    
    return counts_dataarray 

# Call the function to count points in grid cells
grid_counts = count_points_in_grid(lon, lat, lon_bins, lat_bins)

# %%
len(lon_bins)
# Out:
# 49

# %%
o_hit.plot(background=grid_counts, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:13:37 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:13:37 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-02 03:12 to 2023-02-14 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x860.409 with 2 Axes>)

# %%
# Call the function to count points in grid cells
grid_counts_all = count_points_in_grid(lonall, latall, lon_bins, lat_bins)

# %%
o_hit.plot(background=grid_counts_all, clabel='$N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:13:41 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:13:41 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-02 03:12 to 2023-02-14 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x860.409 with 2 Axes>)

# %%
o_hit.plot(background=grid_counts/grid_counts_all, clabel='$n_j / N_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:13:45 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:13:45 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-02 03:12 to 2023-02-14 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x860.409 with 2 Axes>)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(projection=ccrs.Mercator())
ax.gridlines(draw_labels=True)
ax.pcolormesh(grid_counts_all)

# %%
likelihood = grid_counts/grid_counts_all

# %%
likelihood.plot(x=grid_counts.dims[0], y=grid_counts.dims[1], cmap='YlOrRd')
plt.title('likelihood: nj/Nj')
plt.grid()

# %% [markdown]
# ### Equal Prior Probability

# %%
prior = grid_counts_all/len(fwd.trajectory)

# %% [markdown]
# ### Variable Prior Probability

# %% [markdown]
# Variable prior by LATITUDE:

# %%
varprior1 = (grid_counts_all[:,0:3]-4)
varprior2 = (grid_counts_all[:,3:7]+7)
varprior3 = (grid_counts_all[:,7:11]-4)

# %%
varprior = xr.concat([varprior1, varprior2,varprior3], dim='lat_bin')/len(fwd.trajectory)

# %% [markdown]
# Variable prior by LONGITUDE:

# %%
len(grid_counts_all)
# Out:
# 48

# %%
varprior1 = (grid_counts_all[0:23]+(25/2)) 
varprior2 = (grid_counts_all[23:48]-(23/2))

# %%
varprior = xr.concat([varprior1, varprior2], dim='lon_bin')/len(fwd.trajectory)

# %% [markdown]
# Check if sum of all prior probabilities is 1!!!

# %%
np.sum(prior)
# Out:
# <xarray.DataArray ()>
# array(1.)

# %%
np.sum(varprior)
# Out:
# <xarray.DataArray ()>
# array(1.)

# %% [markdown]
# ### Posterior (and norm. const.)

# %%
norm_const = len(hits)/len(fwd.trajectory)
posterior = (likelihood*prior)/norm_const

# %%
norm_const = len(hits)/len(fwd.trajectory)
varposterior = (likelihood*varprior)/norm_const

# %% [markdown]
# For equal prior:

# %%
posterior.plot(x=posterior.dims[0], y=posterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %% [markdown]
# For variable prior:

# %%
varprior.plot(x=varprior.dims[0], y=varprior.dims[1], cmap='YlOrRd')
plt.title('P(Aj): Prior probability')
plt.grid()

# %%
varposterior.plot(x=varposterior.dims[0], y=varposterior.dims[1], cmap='YlOrRd')
plt.title('P(Aj|B): Posterior probability')
plt.grid()

# %%
o_hit.plot(posterior, clabel='Posterior Probability', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:19:31 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:19:31 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-02 03:12 to 2023-02-14 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x860.409 with 2 Axes>)

# %% [markdown]
# # BWD

# %%
lonback = []       # lon for bwd
latback = []       # lat for bwd

for i in range(len(back59.trajectory)):
    lonback.append(back59.isel(trajectory=i).lon.values[-1])
    latback.append(back59.isel(trajectory=i).lat.values[-1])

# %%
grid_counts_back = count_points_in_grid(lonback, latback, lon_bins, lat_bins)

# %%
o_back = opendrift.open(outfile_bwd)
# Out:
# 14:21:36 DEBUG   opendrift.models.basemodel:618: Adding 17 config items from basemodel
# 14:21:36 DEBUG   opendrift.models.basemodel:618: Adding 5 config items from basemodel
# 14:21:36 DEBUG   opendrift.models.basemodel:618: Adding 36 config items from basemodel
# 14:21:37 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.5)
# 14:21:37 DEBUG   opendrift.models.basemodel:618: Adding 14 config items from oceandrift
# 14:21:37 DEBUG   opendrift.models.basemodel:630:   Overwriting config item seed:z
# 14:21:37 DEBUG   opendrift.export.io_netcdf:267: Importing from D:/backtrack/oceandrift_48h/likelihood/bwd0214feb59.nc
# 14:21:37 DEBUG   opendrift.models.basemodel:2449: No elements to deactivate
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:use_auto_landmask -> True
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:coastline_action -> stranding
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_minutes -> 60
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:time_step_output_minutes -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:ocean_only -> True
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:number -> 1
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:max_age_seconds -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:advection_scheme -> runge-kutta4
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:current_uncertainty_uniform -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:horizontal_diffusivity -> 20.0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_uncertainty -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:relative_wind -> False
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_north_of -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_south_of -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_east_of -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:deactivate_west_of -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:origin_marker -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:z -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:wind_drift_factor -> 0.02
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:current_drift_factor -> 1
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:terminal_velocity -> 0.0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_sea_water_velocity -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_sea_water_velocity -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:x_wind -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:x_wind -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:y_wind -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:y_wind -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_x_stress -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_x_stress -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:surface_downward_y_stress -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:surface_downward_y_stress -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_kinetic_energy -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_kinetic_energy -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:turbulent_generic_length_scale -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:turbulent_generic_length_scale -> 0
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:constant:land_binary_mask -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: environment:fallback:land_binary_mask -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_advection -> True
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:vertical_mixing -> False
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:timestep -> 60
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: vertical_mixing:TSprofiles -> False
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:wind_drift_depth -> 0.1
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:stokes_drift -> True
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 14:21:37 DEBUG   opendrift.export.io_netcdf:365: Setting imported config: seed:seafloor -> False
# 14:21:37 INFO    opendrift:78: Returning <class 'opendrift.models.oceandrift.OceanDrift'> object

# %%
o_back.plot(background=grid_counts_back, clabel='$n_j$', fast=True, markersize=.5, lalpha=.02, vmin=0, cmap='YlOrRd')
# Out:
# 14:21:41 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:21:41 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-14 03:12 to 2023-02-02 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x891.355 with 2 Axes>)

# %%
grid_counts_back.plot(x=grid_counts_back.dims[0], y=grid_counts_back.dims[1], cmap='YlOrRd')
plt.title('Backwards nj')
plt.grid()

# %%
fig = plt.figure(1, figsize=(12,10))
ax = fig.add_subplot(111, projection=ccrs.Mercator())
ax.set_extent([18, 22, -36, -39])

ax.gridlines(draw_labels=True)
ax.coastlines(facecolor='black')
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)


### Plotting simulations and drifter trajectories ### 

for i in hits: 
    fwd.isel(trajectory=i).traj.plot(linewidth=0.5, color='blue')

back59.traj.plot(linewidth=0.5,color='red')

# ax.plot(back192.isel(time=0).lon.values, back192.isel(time=0).lat.values, 'ro', markersize=0.5, transform=ccrs.Geodetic())
# for i in hits: 
#     ax.plot(fwd.isel(trajectory=i).isel(time=48).lon.values, fwd.isel(trajectory=i).isel(time=48).lat.values, 'bo', markersize=0.5, transform=ccrs.Geodetic())

d03.sel(time=slice('2023-02-02 03:12:08', '2023-02-14 03:12:08')).traj.plot(color='black')  

plt.gca().autoscale()
plt.title('Opendrift OceanDrift - 23-01-2023 03:12 to 25-01-2023 03:12 UTC (49 steps)')
plt.show()

# %%
o_hit.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 14:22:25 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:22:25 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-02 03:12 to 2023-02-14 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x860.409 with 2 Axes>)

# %%
o_back.plot(background=grid_counts_back/grid_counts, clabel='$bwd_{n_j} / fwd_{n_j}$', cmap='bwr', fast=True, markersize=.5, lalpha=.02, vmin=0, vmax=2)
# Out:
# 14:24:35 DEBUG   opendrift.models.basemodel:3163: Setting up map: corners=None, fast=True, lscale=None
# 14:24:35 WARNING opendrift.models.basemodel:3209: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-02-14 03:12 to 2023-02-02 03:12 UTC (289 steps)'}>,
#  <Figure size 1100x891.355 with 2 Axes>)
